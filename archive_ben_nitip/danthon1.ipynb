# %% [markdown]
# ## Importing Packages

# %%
from math import sin, cos
import s2cell

import numpy as np
import pandas as pd
import datetime as dt

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats
import pingouin as pg

import warnings
warnings.filterwarnings('ignore')

import category_encoders as ce
import sklearn

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import VotingClassifier

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, f1_score, recall_score, precision_score, plot_confusion_matrix, plot_roc_curve, roc_curve
from sklearn.metrics import roc_auc_score, balanced_accuracy_score
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.pipeline import Pipeline as imbPipeline

import warnings
warnings.filterwarnings('ignore')

sns.set()
pd.set_option('display.max_columns', 500)

# %%
samp_df = pd.read_csv('sample_submission.csv')

# %%
test_df = pd.read_csv('data_test.csv')

# %%
train_df = pd.read_csv('data_train.csv')

# %%
raw_irre_df = pd.read_csv('irregularities.csv')

# %%
raw_alerts_df = pd.read_csv('alerts.csv')

# %% [markdown]
# ## Checking Raw Dataset

# %% [markdown]
# > #### Data Sample Submission CSV

# %%
samp_df.head(3)
# Out:
#                        Ids  Labels
# 0  2e69c8bc4_2020-11-29_18   False
# 1  2e6992f24_2020-11-27_18    True
# 2  2e69e8dfc_2020-11-28_15    True

# %%
samp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ids     200 non-null    object
#  1   Labels  200 non-null    bool
# dtypes: bool(1), object(1)
# memory usage: 1.9+ KB

# %% [markdown]
# > #### Data Test CSV

# %%
test_df.head(3)
# Out:
#                        Ids
# 0  2e6992a84_2020-11-25_18
# 1  2e68e62f4_2020-11-29_20
# 2  2e68e81a4_2020-11-27_10

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13841 entries, 0 to 13840
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ids     13841 non-null  object
# dtypes: object(1)
# memory usage: 108.3+ KB

# %% [markdown]
# > #### Data Train CSV

# %%
train_df.head(3)
# Out:
#                        Ids  Labels
# 0  2e69e9384_2020-10-06_13    True
# 1  2e6992c7c_2020-10-02_17    True
# 2  2e69ef474_2020-09-13_19    True

# %%
train_df['Ids'].min()
# Out:
# '2e68c2584_2020-11-08_9'

# %%
train_df['Ids'].max()
# Out:
# '2e6a27984_2020-10-27_20'

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71336 entries, 0 to 71335
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ids     71336 non-null  object
#  1   Labels  71336 non-null  bool
# dtypes: bool(1), object(1)
# memory usage: 627.1+ KB

# %% [markdown]
# > #### Data Irregularities CSV

# %%
raw_irre_df.head(3)
# Out:
#          id  detection_date_millis  update_date_millis             street  \
# 0  12868069          1604733149024       1604735467276  Jatiwaringin Raya
# 1  12420463          1599906813144       1599909295834      Putri Tunggal
# 2  12497533          1601728355356       1601734996933     Ir Haji Juanda
#
#       city is_highway                                               line  \
# 0   Bekasi          t  {"line": [{"x": 106.91014, "y": -6.258107}, {"...
# 1    Depok          f  {"line": [{"x": 106.887821, "y": -6.377016}, {...
# 2  Bandung          f  {"line": [{"x": 107.618629, "y": -6.87556}, {"...
#
#            s2id_center s2token_center  speed  regular_speed  delay_seconds  \
# 0  3344471185277583360      2e69f2d2c  13.03          17.15            299
# 1  3344462996922433536      2e69eb604   6.56          18.00            399
# 2  3344176694402482176      2e68e6fc4   3.36          19.65           1185
#
#    seconds  length  trend   type  severity  jam_level  drivers_count  \
# 0      432    1566      0  Small         5          3             13
# 1      539     984      0  Small         5          3              5
# 2     1294    1212      1  Large         5          4             21
#
#    alerts_count  n_thumbs_up
# 0             0            0
# 1             0            0
# 2             2            0

# %%
raw_irre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352609 entries, 0 to 352608
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     352609 non-null  int64
#  1   detection_date_millis  352609 non-null  int64
#  2   update_date_millis     352609 non-null  int64
#  3   street                 349773 non-null  object
#  4   city                   352609 non-null  object
#  5   is_highway             352609 non-null  object
#  6   line                   352609 non-null  object
#  7   s2id_center            352609 non-null  int64
#  8   s2token_center         352609 non-null  object
#  9   speed                  352609 non-null  float64
#  10  regular_speed          352609 non-null  float64
#  11  delay_seconds          352609 non-null  int64
#  12  seconds                352609 non-null  int64
#  13  length                 352609 non-null  int64
#  14  trend                  352609 non-null  int64
#  15  type                   352609 non-null  object
#  16  severity               352609 non-null  int64
#  17  jam_level              352609 non-null  int64
#  18  drivers_count          352609 non-null  int64
#  19  alerts_count           352609 non-null  int64
#  20  n_thumbs_up            352609 non-null  int64
# dtypes: float64(2), int64(13), object(6)
# memory usage: 56.5+ MB

# %%
raw_irre_df.describe(include='all')
# Out:
#                   id  detection_date_millis  update_date_millis      street  \
# count   3.526090e+05           3.526090e+05        3.526090e+05      349773
# unique           NaN                    NaN                 NaN         408
# top              NaN                    NaN                 NaN  Trans Yogi
# freq             NaN                    NaN                 NaN       23480
# mean    1.267873e+07           1.603120e+12        1.603123e+12         NaN
# std     2.084245e+05           1.993569e+09        1.993727e+09         NaN
# min     1.232382e+07           1.598915e+12        1.598916e+12         NaN
# 25%     1.249558e+07           1.601721e+12        1.601724e+12         NaN
# 50%     1.266650e+07           1.603710e+12        1.603712e+12         NaN
# 75%     1.286050e+07           1.604719e+12        1.604721e+12         NaN
# max     1.306133e+07           1.606053e+12        1.606053e+12         NaN
#
#            city is_highway                                               line  \
# count    352609     352609                                             352609
# unique       21          2                                              22501
# top     Bandung          t  {"line": [{"x": 106.76179, "y": -6.405493}, {"...
# freq     103670     212915                                               5690
# mean        NaN        NaN                                                NaN
# std         NaN        NaN                                                NaN
# min         NaN        NaN                                                NaN
# 25%         NaN        NaN                                                NaN
# 50%         NaN        NaN                                                NaN
# 75%         NaN        NaN                                                NaN
# max         NaN        NaN                                                NaN
#
#          s2id_center s2token_center          speed  regular_speed  \
# count   3.526090e+05         352609  352609.000000  352609.000000
# unique           NaN           1914            NaN            NaN
# top              NaN      2e69e8dfc            NaN            NaN
# freq             NaN           9877            NaN            NaN
# mean    3.344336e+18            NaN       7.084055      19.611386
# std     1.137887e+14            NaN       3.461805       9.268717
# min     3.344136e+18            NaN       0.570000      -1.000000
# 25%     3.344178e+18            NaN       4.600000      13.530000
# 50%     3.344362e+18            NaN       6.390000      18.370000
# 75%     3.344460e+18            NaN       8.800000      23.910000
# max     3.344522e+18            NaN      38.250000    1832.770000
#
#         delay_seconds        seconds         length          trend    type  \
# count   352609.000000  352609.000000  352609.000000  352609.000000  352609
# unique            NaN            NaN            NaN            NaN       4
# top               NaN            NaN            NaN            NaN   Small
# freq              NaN            NaN            NaN            NaN  216308
# mean       666.748478     806.608754    1466.211169      -0.171865     NaN
# std        365.584715     398.243550     836.260998       0.790400     NaN
# min         63.000000     104.000000     500.000000      -1.000000     NaN
# 25%        440.000000     549.000000     852.000000      -1.000000     NaN
# 50%        595.000000     726.000000    1230.000000       0.000000     NaN
# 75%        808.000000     973.000000    1846.000000       0.000000     NaN
# max       7053.000000    6416.000000    8768.000000       1.000000     NaN
#
#         severity      jam_level  drivers_count   alerts_count    n_thumbs_up
# count   352609.0  352609.000000  352609.000000  352609.000000  352609.000000
# unique       NaN            NaN            NaN            NaN            NaN
# top          NaN            NaN            NaN            NaN            NaN
# freq         NaN            NaN            NaN            NaN            NaN
# mean         5.0       3.676041      11.678377       0.460102       0.157585
# std          0.0       0.507719      10.889130       0.957061       0.773910
# min          5.0       1.000000       1.000000       0.000000       0.000000
# 25%          5.0       3.000000       5.000000       0.000000       0.000000
# 50%          5.0       4.000000       8.000000       0.000000       0.000000
# 75%          5.0       4.000000      14.000000       1.000000       0.000000
# max          5.0       4.000000     155.000000      15.000000      25.000000

# %%
# Checking raw datasets

desc = []
for i in raw_irre_df.columns:
    desc.append([i,
                raw_irre_df[i].dtypes,
                raw_irre_df[i].isna().sum(),
                round((raw_irre_df[i].isna().sum())/len(raw_irre_df)*100,2),
                raw_irre_df[i].nunique(),
                raw_irre_df[i].sample(2).values])
pd.DataFrame(desc, columns = ['dataFeatures', 'dataType',' null', 'nullPct', 'unique', 'uniqueSample'])
# Out:
#              dataFeatures dataType   null  nullPct  unique  \
# 0                      id    int64      0      0.0  252609
# 1   detection_date_millis    int64      0      0.0   14830
# 2      update_date_millis    int64      0      0.0  174739
# 3                  street   object   2836      0.8     408
# 4                    city   object      0      0.0      21
# 5              is_highway   object      0      0.0       2
# 6                    line   object      0      0.0   22501
# 7             s2id_center    int64      0      0.0    1914
# 8          s2token_center   object      0      0.0    1914
# 9                   speed  float64      0      0.0    2518
# 10          regular_speed  float64      0      0.0    4727
# 11          delay_seconds    int64      0      0.0    2800
# 12                seconds    int64      0      0.0    2974
# 13                 length    int64      0      0.0    3668
# 14                  trend    int64      0      0.0       3
# 15                   type   object      0      0.0       4
# 16               severity    int64      0      0.0       1
# 17              jam_level    int64      0      0.0       4
# 18          drivers_count    int64      0      0.0     117
# 19           alerts_count    int64      0      0.0      16
# 20            n_thumbs_up    int64      0      0.0      24
#
#                                          uniqueSample
# 0                                [12786359, 12377897]
# 1                      [1604135892106, 1605346076072]
# 2                      [1606030462205, 1603188576227]
# 3                    [Wibawa Mukti 2, Ir Haji Juanda]
# 4                                      [Bogor, Depok]
# 5                                              [t, t]
# 6   [{"line": [{"x": 106.813464, "y": -6.399063}, ...
# 7          [3344176647157841920, 3344350765132021760]
# 8                              [2e698c35c, 2e6994a84]
# 9                                        [8.22, 5.21]
# 10                                       [18.68, 9.4]
# 11                                         [564, 884]
# 12                                        [675, 1120]
# 13                                        [892, 1143]
# 14                                            [0, -1]
# 15                                    [Small, Medium]
# 16                                             [5, 5]
# 17                                             [3, 3]
# 18                                            [19, 5]
# 19                                             [0, 0]
# 20                                             [0, 0]

# %%
a_tes1 = dt.datetime.fromtimestamp(raw_irre_df['detection_date_millis'][0]/1000.0)  # checking

# %%
a_tes2 = dt.datetime.fromtimestamp(raw_irre_df['update_date_millis'][0]/1000.0)  # checking

# %%
a_tes1, a_tes2
# Out:
# (datetime.datetime(2020, 11, 7, 14, 12, 29, 24000),
#  datetime.datetime(2020, 11, 7, 14, 51, 7, 276000))

# %% [markdown]
# > #### Alerts CSV

# %%
raw_alerts_df.head(3)
# Out:
#           id     pub_millis              s2id_15 s2token_15  road_type  \
# 0  177876895  1603331480000  3344466888162803712  2e69eeea4          1
# 1  179156987  1604487892000  3344463130066419712  2e69eb7f4          6
# 2  181688703  1605666614000  3344367648648462336  2e6994a84          7
#
#                 street    city  magvar  reliability  report_description  \
# 0                  NaN   Depok       0            9                 NaN
# 1  N8 Jalan Raya Bogor   Depok     170            7                 NaN
# 2                  NaN  Bekasi       0            8                 NaN
#
#    report_rating  confidence         type            subtype  \
# 0              0           1  ROAD_CLOSED  ROAD_CLOSED_EVENT
# 1              1           1          JAM  JAM_HEAVY_TRAFFIC
# 2              0           1  ROAD_CLOSED  ROAD_CLOSED_EVENT
#
#    report_by_municipality_user  n_thumbs_up   longitude  latitude
# 0                          NaN          NaN  106.788545 -6.359846
# 1                          NaN          0.0  106.867141 -6.383855
# 2                          NaN          NaN  106.921974 -6.379087

# %%
raw_alerts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7800662 entries, 0 to 7800661
# Data columns (total 18 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   id                           int64
#  1   pub_millis                   int64
#  2   s2id_15                      int64
#  3   s2token_15                   object
#  4   road_type                    int64
#  5   street                       object
#  6   city                         object
#  7   magvar                       int64
#  8   reliability                  int64
#  9   report_description           float64
#  10  report_rating                int64
#  11  confidence                   int64
#  12  type                         object
#  13  subtype                      object
#  14  report_by_municipality_user  float64
#  15  n_thumbs_up                  float64
#  16  longitude                    float64
#  17  latitude                     float64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 1.0+ GB

# %%
raw_alerts_df.describe(include='all')
# Out:
#                   id    pub_millis       s2id_15 s2token_15     road_type  \
# count   7.800662e+06  7.800662e+06  7.800662e+06    7800662  7.800662e+06
# unique           NaN           NaN           NaN       4341           NaN
# top              NaN           NaN           NaN  2e68e64c4           NaN
# freq             NaN           NaN           NaN     265609           NaN
# mean    1.740590e+08  1.602244e+12  3.344264e+18        NaN  3.846760e+00
# std     4.744770e+06  2.021204e+09  1.066108e+14        NaN  2.883360e+00
# min     1.662550e+08  1.598895e+12  3.344136e+18        NaN  1.000000e+00
# 25%     1.699264e+08  1.600524e+12  3.344176e+18        NaN  2.000000e+00
# 50%     1.734051e+08  1.602122e+12  3.344178e+18        NaN  2.000000e+00
# 75%     1.779916e+08  1.603854e+12  3.344362e+18        NaN  7.000000e+00
# max     1.835628e+08  1.606062e+12  3.344529e+18        NaN  2.200000e+01
#
#                 street     city        magvar   reliability  \
# count          6668993  7800662  7.800662e+06  7.800662e+06
# unique            2144       20           NaN           NaN
# top     Ir Haji Juanda  Bandung           NaN           NaN
# freq            626736  4463547           NaN           NaN
# mean               NaN      NaN  8.904586e+01  6.443702e+00
# std                NaN      NaN  1.258826e+02  1.504663e+00
# min                NaN      NaN  0.000000e+00  5.000000e+00
# 25%                NaN      NaN  0.000000e+00  6.000000e+00
# 50%                NaN      NaN  0.000000e+00  6.000000e+00
# 75%                NaN      NaN  1.870000e+02  6.000000e+00
# max                NaN      NaN  3.590000e+02  1.000000e+01
#
#         report_description  report_rating    confidence         type  \
# count                  0.0   7.800662e+06  7.800662e+06      7800662
# unique                 NaN            NaN           NaN            4
# top                    NaN            NaN           NaN  ROAD_CLOSED
# freq                   NaN            NaN           NaN      4269581
# mean                   NaN   1.176968e+00  3.812903e-01          NaN
# std                    NaN   1.696724e+00  1.018619e+00          NaN
# min                    NaN   0.000000e+00  0.000000e+00          NaN
# 25%                    NaN   0.000000e+00  0.000000e+00          NaN
# 50%                    NaN   0.000000e+00  0.000000e+00          NaN
# 75%                    NaN   2.000000e+00  0.000000e+00          NaN
# max                    NaN   5.000000e+00  5.000000e+00          NaN
#
#                   subtype  report_by_municipality_user  n_thumbs_up  \
# count             7603664                          0.0    2515124.0
# unique                 26                          NaN          NaN
# top     ROAD_CLOSED_EVENT                          NaN          NaN
# freq              4268894                          NaN          NaN
# mean                  NaN                          NaN          0.0
# std                   NaN                          NaN          0.0
# min                   NaN                          NaN          0.0
# 25%                   NaN                          NaN          0.0
# 50%                   NaN                          NaN          0.0
# 75%                   NaN                          NaN          0.0
# max                   NaN                          NaN          0.0
#
#            longitude      latitude
# count   7.800662e+06  7.800662e+06
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean    1.073486e+02 -6.671771e+00
# std     3.222071e-01  2.960890e-01
# min     1.067135e+02 -6.968834e+00
# 25%     1.070087e+02 -6.919966e+00
# 50%     1.076032e+02 -6.893167e+00
# 75%     1.076130e+02 -6.346568e+00
# max     1.077262e+02 -6.072345e+00

# %%
# Checking raw datasets

desc = []
for i in raw_alerts_df.columns:
    desc.append([i,
                raw_alerts_df[i].dtypes,
                raw_alerts_df[i].isna().sum(),
                round((raw_alerts_df[i].isna().sum())/len(raw_alerts_df)*100,2),
                raw_alerts_df[i].nunique(),
                raw_alerts_df[i].sample(2).values])
pd.DataFrame(desc, columns = ['dataFeatures', 'dataType',' null', 'nullPct', 'unique', 'uniqueSample'])
# Out:
#                    dataFeatures dataType     null  nullPct   unique  \
# 0                            id    int64        0     0.00  6800662
# 1                    pub_millis    int64        0     0.00    55193
# 2                       s2id_15    int64        0     0.00     4341
# 3                    s2token_15   object        0     0.00     4341
# 4                     road_type    int64        0     0.00       10
# 5                        street   object  1131669    14.51     2144
# 6                          city   object        0     0.00       20
# 7                        magvar    int64        0     0.00      360
# 8                   reliability    int64        0     0.00        6
# 9            report_description  float64  7800662   100.00        0
# 10                report_rating    int64        0     0.00        6
# 11                   confidence    int64        0     0.00        6
# 12                         type   object        0     0.00        4
# 13                      subtype   object   196998     2.53       26
# 14  report_by_municipality_user  float64  7800662   100.00        0
# 15                  n_thumbs_up  float64  5285538    67.76        1
# 16                    longitude  float64        0     0.00    48058
# 17                     latitude  float64        0     0.00    47190
#
#                                          uniqueSample
# 0                              [178218318, 171090999]
# 1                      [1599123395000, 1603521511000]
# 2          [3344175768837029888, 3344175919160885248]
# 3                              [2e699b954, 2e68e89ec]
# 4                                              [2, 2]
# 5                                   [Jalan Aceh, BKR]
# 6                                  [Bandung, Bandung]
# 7                                             [33, 0]
# 8                                              [6, 8]
# 9                                          [nan, nan]
# 10                                             [0, 0]
# 11                                             [0, 0]
# 12                          [WEATHERHAZARD, ACCIDENT]
# 13  [JAM_STAND_STILL_TRAFFIC, HAZARD_ON_ROAD_POT_H...
# 14                                         [nan, nan]
# 15                                         [nan, 0.0]
# 16                           [107.603182, 107.616168]
# 17                   [-6.9244119999999985, -6.906831]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# > #### Adding "Ids" Column in "Alerts"

# %%
alerts_df = raw_alerts_df.copy()

# %%
alerts_df.head(3)
# Out:
#           id     pub_millis              s2id_15 s2token_15  road_type  \
# 0  177876895  1603331480000  3344466888162803712  2e69eeea4          1
# 1  179156987  1604487892000  3344463130066419712  2e69eb7f4          6
# 2  181688703  1605666614000  3344367648648462336  2e6994a84          7
#
#                 street    city  magvar  reliability  report_description  \
# 0                  NaN   Depok       0            9                 NaN
# 1  N8 Jalan Raya Bogor   Depok     170            7                 NaN
# 2                  NaN  Bekasi       0            8                 NaN
#
#    report_rating  confidence         type            subtype  \
# 0              0           1  ROAD_CLOSED  ROAD_CLOSED_EVENT
# 1              1           1          JAM  JAM_HEAVY_TRAFFIC
# 2              0           1  ROAD_CLOSED  ROAD_CLOSED_EVENT
#
#    report_by_municipality_user  n_thumbs_up   longitude  latitude
# 0                          NaN          NaN  106.788545 -6.359846
# 1                          NaN          0.0  106.867141 -6.383855
# 2                          NaN          NaN  106.921974 -6.379087

# %%
alerts_df['dates'] = [dt.datetime.fromtimestamp(i/1000.0) for i in alerts_df['pub_millis']]

# %%
alerts_df['dates'][:3]  # checking
# Out:
# 0   2020-10-22 08:51:20
# 1   2020-11-04 18:04:52
# 2   2020-11-18 09:30:14
# Name: dates, dtype: datetime64[ns]

# %%
alerts_df['date'] = [i.strftime("%Y-%m-%d") for i in alerts_df['dates']]
alerts_df['hour'] = [i.strftime("%H") for i in alerts_df['dates']]
alerts_df['hour'] = alerts_df['hour'].str.replace("0", "", 1)
alerts_df['Ids'] = alerts_df.s2token_15 + '_' + alerts_df.date + '_' + alerts_df.hour

# %%
alerts_df[['Ids']]  # checking
# Out:
#                              Ids
# 0         2e69eeea4_2020-10-22_8
# 1        2e69eb7f4_2020-11-04_18
# 2         2e6994a84_2020-11-18_9
# 3        2e699ad9c_2020-10-05_18
# 4         2e69eec0c_2020-10-12_7
# ...                          ...
# 7800657   2e68e6564_2020-09-28_9
# 7800658  2e698a284_2020-10-04_18
# 7800659   2e68e64cc_2020-09-02_9
# 7800660  2e69927fc_2020-10-07_19
# 7800661   2e698c494_2020-11-14_0
#
# [7800662 rows x 1 columns]

# %% [markdown]
# > #### Adding "Ids" Column in "Irregularities"

# %%
irre_df = raw_irre_df.copy()

# %%
irre_df.head(3)
# Out:
#          id  detection_date_millis  update_date_millis             street  \
# 0  12868069          1604733149024       1604735467276  Jatiwaringin Raya
# 1  12420463          1599906813144       1599909295834      Putri Tunggal
# 2  12497533          1601728355356       1601734996933     Ir Haji Juanda
#
#       city is_highway                                               line  \
# 0   Bekasi          t  {"line": [{"x": 106.91014, "y": -6.258107}, {"...
# 1    Depok          f  {"line": [{"x": 106.887821, "y": -6.377016}, {...
# 2  Bandung          f  {"line": [{"x": 107.618629, "y": -6.87556}, {"...
#
#            s2id_center s2token_center  speed  regular_speed  delay_seconds  \
# 0  3344471185277583360      2e69f2d2c  13.03          17.15            299
# 1  3344462996922433536      2e69eb604   6.56          18.00            399
# 2  3344176694402482176      2e68e6fc4   3.36          19.65           1185
#
#    seconds  length  trend   type  severity  jam_level  drivers_count  \
# 0      432    1566      0  Small         5          3             13
# 1      539     984      0  Small         5          3              5
# 2     1294    1212      1  Large         5          4             21
#
#    alerts_count  n_thumbs_up
# 0             0            0
# 1             0            0
# 2             2            0

# %%
irre_df['dates'] = [dt.datetime.fromtimestamp(i/1000.0) for i in irre_df['detection_date_millis']]

# %%
irre_df['dates'][:3]  # checking
# Out:
# 0   2020-11-07 14:12:29.024
# 1   2020-09-12 17:33:33.144
# 2   2020-10-03 19:32:35.356
# Name: dates, dtype: datetime64[ns]

# %%
irre_df['date'] = [i.strftime("%Y-%m-%d") for i in irre_df['dates']]
irre_df['hour'] = [i.strftime("%H") for i in irre_df['dates']]
irre_df['hour'] = irre_df['hour'].str.replace("0", "", 1)
irre_df['Ids'] = irre_df.s2token_center + '_' + irre_df.date + '_' + irre_df.hour

# %%
irre_df[['Ids']]  # checking
# Out:
#                             Ids
# 0       2e69f2d2c_2020-11-07_14
# 1       2e69eb604_2020-09-12_17
# 2       2e68e6fc4_2020-10-03_19
# 3       2e698c034_2020-10-10_13
# 4       2e698e5bc_2020-09-01_17
# ...                         ...
# 352604  2e69c41c4_2020-09-05_13
# 352605  2e68e8144_2020-10-18_14
# 352606  2e6984e2c_2020-11-01_23
# 352607   2e68e71fc_2020-10-31_1
# 352608  2e698fb3c_2020-11-10_17
#
# [352609 rows x 1 columns]

# %% [markdown]
# > #### Combining "Alerts" and "Irregularities"

# %%
comb_df = pd.merge(alerts_df, irre_df, on='Ids')

# %%
# comb_df = pd.merge(alerts_df, irre_df, left_on=['Ids', 's2token_15', 's2id_15', 'street'], right_on=['Ids', 's2token_center', 's2id_center', 'street'])  # checking

# %%
comb_df = pd.merge(train_df, comb_df, on='Ids')

# %%
comb_df
# Out:
#                              Ids  Labels       id_x     pub_millis  \
# 0        2e68e7d0c_2020-10-14_17    True  174293857  1602671462000
# 1        2e68e7d0c_2020-10-14_17    True  174293857  1602671462000
# 2        2e68e7d0c_2020-10-14_17    True  174293857  1602671462000
# 3        2e68e7d0c_2020-10-14_17    True  174293857  1602671462000
# 4        2e68e7d0c_2020-10-14_17    True  174293857  1602671462000
# ...                          ...     ...        ...            ...
# 3188055  2e68e6874_2020-11-22_17    True  182152990  1606041616000
# 3188056  2e68e6874_2020-11-22_17    True  182152990  1606041616000
# 3188057  2e68e6874_2020-11-22_17    True  182152990  1606041616000
# 3188058  2e68e6874_2020-11-22_17    True  182152990  1606041616000
# 3188059  2e68e6874_2020-11-22_17    True  182152990  1606041616000
#
#                      s2id_15 s2token_15  road_type                street_x  \
# 0        3344177607083032576  2e68e7d0c          7                   Laswi
# 1        3344177607083032576  2e68e7d0c          7                   Laswi
# 2        3344177607083032576  2e68e7d0c          7                   Laswi
# 3        3344177607083032576  2e68e7d0c          7                   Laswi
# 4        3344177607083032576  2e68e7d0c          7                   Laswi
# ...                      ...        ...        ...                     ...
# 3188055  3344176191891308544  2e68e6874          2  Prof Dr Surya Sumantri
# 3188056  3344176191891308544  2e68e6874          2  Prof Dr Surya Sumantri
# 3188057  3344176191891308544  2e68e6874          2  Prof Dr Surya Sumantri
# 3188058  3344176191891308544  2e68e6874          2  Prof Dr Surya Sumantri
# 3188059  3344176191891308544  2e68e6874          2  Prof Dr Surya Sumantri
#
#           city_x  magvar  reliability  report_description  report_rating  \
# 0        Bandung     194            6                 NaN              5
# 1        Bandung     194            6                 NaN              5
# 2        Bandung     194            6                 NaN              5
# 3        Bandung     194            6                 NaN              5
# 4        Bandung     194            6                 NaN              5
# ...          ...     ...          ...                 ...            ...
# 3188055  Bandung     181            6                 NaN              1
# 3188056  Bandung     181            6                 NaN              1
# 3188057  Bandung     181            6                 NaN              1
# 3188058  Bandung     181            6                 NaN              1
# 3188059  Bandung     181            6                 NaN              1
#
#          confidence         type_x                         subtype  \
# 0                 0  WEATHERHAZARD  HAZARD_ON_SHOULDER_CAR_STOPPED
# 1                 0  WEATHERHAZARD  HAZARD_ON_SHOULDER_CAR_STOPPED
# 2                 0  WEATHERHAZARD  HAZARD_ON_SHOULDER_CAR_STOPPED
# 3                 0  WEATHERHAZARD  HAZARD_ON_SHOULDER_CAR_STOPPED
# 4                 0  WEATHERHAZARD  HAZARD_ON_SHOULDER_CAR_STOPPED
# ...             ...            ...                             ...
# 3188055           0            JAM               JAM_HEAVY_TRAFFIC
# 3188056           0            JAM               JAM_HEAVY_TRAFFIC
# 3188057           0            JAM               JAM_HEAVY_TRAFFIC
# 3188058           0            JAM               JAM_HEAVY_TRAFFIC
# 3188059           0            JAM               JAM_HEAVY_TRAFFIC
#
#          report_by_municipality_user  n_thumbs_up_x   longitude  latitude  \
# 0                                NaN            NaN  107.631025 -6.920342
# 1                                NaN            NaN  107.631025 -6.920342
# 2                                NaN            NaN  107.631025 -6.920342
# 3                                NaN            NaN  107.631025 -6.920342
# 4                                NaN            NaN  107.631025 -6.920342
# ...                              ...            ...         ...       ...
# 3188055                          NaN            NaN  107.581387 -6.886732
# 3188056                          NaN            NaN  107.581387 -6.886732
# 3188057                          NaN            NaN  107.581387 -6.886732
# 3188058                          NaN            NaN  107.581387 -6.886732
# 3188059                          NaN            NaN  107.581387 -6.886732
#
#                     dates_x      date_x hour_x      id_y  \
# 0       2020-10-14 17:31:02  2020-10-14     17  12565640
# 1       2020-10-14 17:31:02  2020-10-14     17  12565622
# 2       2020-10-14 17:31:02  2020-10-14     17  12565631
# 3       2020-10-14 17:31:02  2020-10-14     17  12565651
# 4       2020-10-14 17:31:02  2020-10-14     17  12565622
# ...                     ...         ...    ...       ...
# 3188055 2020-11-22 17:40:16  2020-11-22     17  13058773
# 3188056 2020-11-22 17:40:16  2020-11-22     17  13058747
# 3188057 2020-11-22 17:40:16  2020-11-22     17  13058747
# 3188058 2020-11-22 17:40:16  2020-11-22     17  13058725
# 3188059 2020-11-22 17:40:16  2020-11-22     17  13058725
#
#          detection_date_millis  update_date_millis                street_y  \
# 0                1602671143526       1602672140763                   Laswi
# 1                1602671143526       1602672062891                   Laswi
# 2                1602671143526       1602672062891                   Laswi
# 3                1602671143526       1602672216632                   Laswi
# 4                1602671143526       1602672062891                   Laswi
# ...                        ...                 ...                     ...
# 3188055          1606041892092       1606043055591  Prof Dr Surya Sumantri
# 3188056          1606041892092       1606043055591  Prof Dr Surya Sumantri
# 3188057          1606041892092       1606043055591  Prof Dr Surya Sumantri
# 3188058          1606041892092       1606042977100  Prof Dr Surya Sumantri
# 3188059          1606041892092       1606042977100  Prof Dr Surya Sumantri
#
#           city_y is_highway  \
# 0        Bandung          t
# 1        Bandung          t
# 2        Bandung          t
# 3        Bandung          t
# 4        Bandung          t
# ...          ...        ...
# 3188055  Bandung          f
# 3188056  Bandung          f
# 3188057  Bandung          f
# 3188058  Bandung          f
# 3188059  Bandung          f
#
#                                                       line  \
# 0        {"line": [{"x": 107.630985, "y": -6.917677}, {...
# 1        {"line": [{"x": 107.630985, "y": -6.917677}, {...
# 2        {"line": [{"x": 107.630985, "y": -6.917677}, {...
# 3        {"line": [{"x": 107.630985, "y": -6.917677}, {...
# 4        {"line": [{"x": 107.630985, "y": -6.917677}, {...
# ...                                                    ...
# 3188055  {"line": [{"x": 107.58148, "y": -6.882219}, {"...
# 3188056  {"line": [{"x": 107.58148, "y": -6.882219}, {"...
# 3188057  {"line": [{"x": 107.58148, "y": -6.882219}, {"...
# 3188058  {"line": [{"x": 107.58148, "y": -6.882219}, {"...
# 3188059  {"line": [{"x": 107.58148, "y": -6.882219}, {"...
#
#                  s2id_center s2token_center  speed  regular_speed  \
# 0        3344177607083032576      2e68e7d0c   4.21          19.21
# 1        3344177607083032576      2e68e7d0c   4.17          18.78
# 2        3344177607083032576      2e68e7d0c   4.17          18.78
# 3        3344177607083032576      2e68e7d0c   4.15          19.47
# 4        3344177607083032576      2e68e7d0c   4.17          18.78
# ...                      ...            ...    ...            ...
# 3188055  3344176191891308544      2e68e6874   3.97          16.06
# 3188056  3344176191891308544      2e68e6874   3.97          16.06
# 3188057  3344176191891308544      2e68e6874   3.97          16.06
# 3188058  3344176191891308544      2e68e6874   4.00          15.63
# 3188059  3344176191891308544      2e68e6874   4.00          15.63
#
#          delay_seconds  seconds  length  trend  type_y  severity  jam_level  \
# 0                  514      583     683      0  Medium         5          4
# 1                  519      588     683      1  Medium         5          4
# 2                  519      588     683      1  Medium         5          4
# 3                  522      591     683      0  Medium         5          4
# 4                  519      588     683      1  Medium         5          4
# ...                ...      ...     ...    ...     ...       ...        ...
# 3188055            847      935    1033      1  Medium         5          4
# 3188056            847      935    1033      1  Medium         5          4
# 3188057            847      935    1033      1  Medium         5          4
# 3188058            839      927    1033      1   Small         5          4
# 3188059            839      927    1033      1   Small         5          4
#
#          drivers_count  alerts_count  n_thumbs_up_y                 dates_y  \
# 0                    5             6              3 2020-10-14 17:25:43.526
# 1                    5             6              2 2020-10-14 17:25:43.526
# 2                    5             6              2 2020-10-14 17:25:43.526
# 3                    5             6              3 2020-10-14 17:25:43.526
# 4                    5             6              2 2020-10-14 17:25:43.526
# ...                ...           ...            ...                     ...
# 3188055              8             2              1 2020-11-22 17:44:52.092
# 3188056              8             2              1 2020-11-22 17:44:52.092
# 3188057              8             2              1 2020-11-22 17:44:52.092
# 3188058              8             2              1 2020-11-22 17:44:52.092
# 3188059              8             2              1 2020-11-22 17:44:52.092
#
#              date_y hour_y
# 0        2020-10-14     17
# 1        2020-10-14     17
# 2        2020-10-14     17
# 3        2020-10-14     17
# 4        2020-10-14     17
# ...             ...    ...
# 3188055  2020-11-22     17
# 3188056  2020-11-22     17
# 3188057  2020-11-22     17
# 3188058  2020-11-22     17
# 3188059  2020-11-22     17
#
# [3188060 rows x 47 columns]

# %%
(comb_df.isna().sum()/len(comb_df)*100).nlargest(10)
# Out:
# report_description             100.000000
# report_by_municipality_user    100.000000
# n_thumbs_up_x                   75.327064
# subtype                          5.002415
# street_x                         3.020614
# street_y                         0.969367
# Ids                              0.000000
# Labels                           0.000000
# id_x                             0.000000
# pub_millis                       0.000000
# dtype: float64

# %% [markdown]
# > #### Removing Features

# %%
comb_df.drop(columns=['report_description', 'report_by_municipality_user'], inplace=True)

# %% [markdown]
# > #### Converting Labels to Zeros and Ones

# %%
comb_df['Labels'] = np.where(comb_df['Labels']==True, 1, 0)

# %%
comb_df.head(3)
# Out:
#                        Ids  Labels       id_x     pub_millis  \
# 0  2e68e7d0c_2020-10-14_17       1  174293857  1602671462000
# 1  2e68e7d0c_2020-10-14_17       1  174293857  1602671462000
# 2  2e68e7d0c_2020-10-14_17       1  174293857  1602671462000
#
#                s2id_15 s2token_15  road_type street_x   city_x  magvar  \
# 0  3344177607083032576  2e68e7d0c          7    Laswi  Bandung     194
# 1  3344177607083032576  2e68e7d0c          7    Laswi  Bandung     194
# 2  3344177607083032576  2e68e7d0c          7    Laswi  Bandung     194
#
#    reliability  report_rating  confidence         type_x  \
# 0            6              5           0  WEATHERHAZARD
# 1            6              5           0  WEATHERHAZARD
# 2            6              5           0  WEATHERHAZARD
#
#                           subtype  n_thumbs_up_x   longitude  latitude  \
# 0  HAZARD_ON_SHOULDER_CAR_STOPPED            NaN  107.631025 -6.920342
# 1  HAZARD_ON_SHOULDER_CAR_STOPPED            NaN  107.631025 -6.920342
# 2  HAZARD_ON_SHOULDER_CAR_STOPPED            NaN  107.631025 -6.920342
#
#               dates_x      date_x hour_x      id_y  detection_date_millis  \
# 0 2020-10-14 17:31:02  2020-10-14     17  12565640          1602671143526
# 1 2020-10-14 17:31:02  2020-10-14     17  12565622          1602671143526
# 2 2020-10-14 17:31:02  2020-10-14     17  12565631          1602671143526
#
#    update_date_millis street_y   city_y is_highway  \
# 0       1602672140763    Laswi  Bandung          t
# 1       1602672062891    Laswi  Bandung          t
# 2       1602672062891    Laswi  Bandung          t
#
#                                                 line          s2id_center  \
# 0  {"line": [{"x": 107.630985, "y": -6.917677}, {...  3344177607083032576
# 1  {"line": [{"x": 107.630985, "y": -6.917677}, {...  3344177607083032576
# 2  {"line": [{"x": 107.630985, "y": -6.917677}, {...  3344177607083032576
#
#   s2token_center  speed  regular_speed  delay_seconds  seconds  length  trend  \
# 0      2e68e7d0c   4.21          19.21            514      583     683      0
# 1      2e68e7d0c   4.17          18.78            519      588     683      1
# 2      2e68e7d0c   4.17          18.78            519      588     683      1
#
#    type_y  severity  jam_level  drivers_count  alerts_count  n_thumbs_up_y  \
# 0  Medium         5          4              5             6              3
# 1  Medium         5          4              5             6              2
# 2  Medium         5          4              5             6              2
#
#                   dates_y      date_y hour_y
# 0 2020-10-14 17:25:43.526  2020-10-14     17
# 1 2020-10-14 17:25:43.526  2020-10-14     17
# 2 2020-10-14 17:25:43.526  2020-10-14     17

# %%
comb_df.columns
# Out:
# Index(['Ids', 'Labels', 'id_x', 'pub_millis', 's2id_15', 's2token_15',
#        'road_type', 'street_x', 'city_x', 'magvar', 'reliability',
#        'report_rating', 'confidence', 'type_x', 'subtype', 'n_thumbs_up_x',
#        'longitude', 'latitude', 'dates_x', 'date_x', 'hour_x', 'id_y',
#        'detection_date_millis', 'update_date_millis', 'street_y', 'city_y',
#        'is_highway', 'line', 's2id_center', 's2token_center', 'speed',
#        'regular_speed', 'delay_seconds', 'seconds', 'length', 'trend',
#        'type_y', 'severity', 'jam_level', 'drivers_count', 'alerts_count',
#        'n_thumbs_up_y', 'dates_y', 'date_y', 'hour_y'],
#       dtype='object')

# %% [markdown]
# > #### Merging Columns

# %%
data = comb_df[['Ids', 'Labels', 's2id_15', 's2token_15', 'road_type', 'street_x', 'city_x', 'magvar', 'reliability', 'report_rating', 'confidence', 'type_x', 'subtype', 'longitude', 'latitude', 'dates_x', 'date_x', 'hour_x', 'is_highway', 'line', 'speed',
       'regular_speed', 'delay_seconds', 'seconds', 'length', 'trend', 'type_y', 'severity', 'jam_level', 'drivers_count', 'alerts_count', 'n_thumbs_up_y']]

# %%
data.head(3)
# Out:
#                        Ids  Labels              s2id_15 s2token_15  road_type  \
# 0  2e68e7d0c_2020-10-14_17       1  3344177607083032576  2e68e7d0c          7
# 1  2e68e7d0c_2020-10-14_17       1  3344177607083032576  2e68e7d0c          7
# 2  2e68e7d0c_2020-10-14_17       1  3344177607083032576  2e68e7d0c          7
#
#   street_x   city_x  magvar  reliability  report_rating  confidence  \
# 0    Laswi  Bandung     194            6              5           0
# 1    Laswi  Bandung     194            6              5           0
# 2    Laswi  Bandung     194            6              5           0
#
#           type_x                         subtype   longitude  latitude  \
# 0  WEATHERHAZARD  HAZARD_ON_SHOULDER_CAR_STOPPED  107.631025 -6.920342
# 1  WEATHERHAZARD  HAZARD_ON_SHOULDER_CAR_STOPPED  107.631025 -6.920342
# 2  WEATHERHAZARD  HAZARD_ON_SHOULDER_CAR_STOPPED  107.631025 -6.920342
#
#               dates_x      date_x hour_x is_highway  \
# 0 2020-10-14 17:31:02  2020-10-14     17          t
# 1 2020-10-14 17:31:02  2020-10-14     17          t
# 2 2020-10-14 17:31:02  2020-10-14     17          t
#
#                                                 line  speed  regular_speed  \
# 0  {"line": [{"x": 107.630985, "y": -6.917677}, {...   4.21          19.21
# 1  {"line": [{"x": 107.630985, "y": -6.917677}, {...   4.17          18.78
# 2  {"line": [{"x": 107.630985, "y": -6.917677}, {...   4.17          18.78
#
#    delay_seconds  seconds  length  trend  type_y  severity  jam_level  \
# 0            514      583     683      0  Medium         5          4
# 1            519      588     683      1  Medium         5          4
# 2            519      588     683      1  Medium         5          4
#
#    drivers_count  alerts_count  n_thumbs_up_y
# 0              5             6              3
# 1              5             6              2
# 2              5             6              2

# %%
# Checking

print(len(data.columns))
print(comb_df['s2token_15'].nunique())
# Out:
# 32
# 930

# %% [markdown]
# - __Determining the Labels__

# %%
data[data['Labels']==1]['jam_level'].value_counts()
# Out:
# 4    2377452
# 3     689364
# 2      21067
# 1        926
# Name: jam_level, dtype: int64

# %%
data[data['Labels']==0]['jam_level'].value_counts()
# Out:
# 4    74803
# 3    23117
# 2     1331
# Name: jam_level, dtype: int64

# %% [markdown]
# 1 is High Jam Reports and 0 is No Congestion

# %%
# Data is highly unbalanced, balancing method needs to be implemented

data['Labels'].value_counts(normalize=True).plot(kind='pie')
plt.title('Ratio Between High Jam Reports (1) and No Congestion (0)')
# Out:
# Text(0.5, 1.0, 'Ratio Between High Jam Reports (1) and No Congestion (0)')

# %%
data_ml = data[['latitude', 'longitude', 'date_x', 'hour_x', 'Labels']]
data_ml.rename(columns={'date_x': 'date', 'hour_x': 'hour'}, inplace=True)

# %%
data_ml['date'] = data_ml['date'].str.split('-')

# %%
data_ml['year'] = data_ml['date'].apply(lambda x: int(x[0]))
data_ml['month'] = data_ml['date'].apply(lambda x: int(x[1]))
data_ml['day'] = data_ml['date'].apply(lambda x: int(x[2]))
data_ml['hour'] = data_ml['hour'].astype('int')

# %%
data_ml['x'] = data_ml['latitude'].apply(cos) * data_ml['longitude'].apply(cos)
data_ml['y'] = data_ml['latitude'].apply(cos) * data_ml['longitude'].apply(sin)
data_ml['z'] = data_ml['latitude'].apply(sin)

# %%
data_ml2 = data_ml.copy()

# %%
data_ml2.to_csv('data_ml2.csv', index=False)

# %%
data_ml = data_ml[['x', 'y', 'z', 'year', 'month', 'day', 'hour', 'Labels']]

# %%
data_ml.head(3)
# Out:
#           x         y         z  year  month  day  hour  Labels
# 0  0.550197  0.585971 -0.594912  2020     10   14    17       1
# 1  0.550197  0.585971 -0.594912  2020     10   14    17       1
# 2  0.550197  0.585971 -0.594912  2020     10   14    17       1

# %% [markdown]
# > #### Selecting Feature and Target

# %%
X = data_ml[['x', 'y', 'z', 'year', 'month', 'day', 'hour']]
y = data_ml['Labels']

# %%
X.head()
# Out:
#           x         y         z  year  month  day  hour
# 0  0.550197  0.585971 -0.594912  2020     10   14    17
# 1  0.550197  0.585971 -0.594912  2020     10   14    17
# 2  0.550197  0.585971 -0.594912  2020     10   14    17
# 3  0.550197  0.585971 -0.594912  2020     10   14    17
# 4  0.550197  0.585971 -0.594912  2020     10   14    17

# %%
y[:5]
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Labels, dtype: int32

# %% [markdown]
# > #### Splitting Training-validation Set and Testing Set

# %%
# Splitting training-validation set dan testing set

X_train_val, X_test, y_train_val, y_test= train_test_split(X,y,stratify=y, random_state=2021,test_size=0.2)
skfold = StratifiedKFold(n_splits = 5, random_state=2021, shuffle=True)

# %% [markdown]
# ## Creating Benchmark Models - 1

# %%
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %% [markdown]
# > #### Creating Logistic Regression Benchmark

# %%
logreg = LogisticRegression(random_state=2021)

transformer_logreg_bench = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour'])
], remainder='passthrough')

pipe_logreg_bench = imbPipeline([
    ('transformer', transformer_logreg_bench),
    ('logreg', logreg)
])

# %%
logreg_bench_cv = cross_val_score(pipe_logreg_bench, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV Logreg Benchmark:', logreg_bench_cv)
print('CV Logreg Benchmark Mean:', logreg_bench_cv.mean())
# CV Logreg Benchmark: [0.98398971 0.98398161 0.98401905 0.98396944 0.98398563]
# CV Logreg Benchmark Mean: 0.9839890860990159
# Out:
# CV Logreg Benchmark: [0.98398971 0.98398161 0.98401905 0.98396944 0.98398563]
# CV Logreg Benchmark Mean: 0.9839890860990159

# %% [markdown]
# > #### Creating Decision Tree Classifier Benchmark

# %%
dtc = DecisionTreeClassifier(random_state=2021)

transformer_dtc_bench = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour'])
], remainder='passthrough')

pipe_dtc_bench = Pipeline([
    ('transformer', transformer_dtc_bench),
    ('dtc', dtc)
])

# %%
dtc_bench_cv = cross_val_score(pipe_dtc_bench, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV DTC Benchmark1:', dtc_bench_cv)
print('CV DTC Benchmark1 Mean:', dtc_bench_cv.mean())
# CV DTC Benchmark1: [1.         1.         1.         0.99999899 1.        ]
# CV DTC Benchmark1 Mean: 0.9999997976566618
# Out:
# CV DTC Benchmark1: [1.         1.         1.         0.99999899 1.        ]
# CV DTC Benchmark1 Mean: 0.9999997976566618

# %% [markdown]
# > #### Creating Decision Tree Classifier Benchmark 2 - smote, PF

# %%
dtc = DecisionTreeClassifier(random_state=2021)
smote = SMOTE(random_state=2021)

transformer_dtc_bench2 = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour']),
    ('poly', PolynomialFeatures(degree=2, include_bias=False), ['x','y','z'])
], remainder='passthrough')

pipe_dtc_bench2 = imbPipeline([
    ('transformer', transformer_dtc_bench2),
    ('smote', smote),
    ('dtc', dtc)
])

# %%
dtc_bench2_cv = cross_val_score(pipe_dtc_bench2, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV DTC Benchmark2:', dtc_bench2_cv)
print('CV DTC Benchmark2 Mean:', dtc_bench2_cv.mean())
# Out:
# CV DTC Benchmark2: [1.         1.         1.         0.99999899 1.        ]
# CV DTC Benchmark2 Mean: 0.9999997976566618

# %% [markdown]
# > #### Creating XGBoost Classifier Benchmark

# %%
xgbc = XGBClassifier(random_state=2021)

transformer_xgbc_bench = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour'])
], remainder='passthrough')

pipe_xgbc_bench = Pipeline([
    ('transformer', transformer_xgbc_bench),
    ('xgbc', xgbc)
])

# %%
xgbc_bench_cv = cross_val_score(pipe_xgbc_bench, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV XGBC Benchmark:', xgbc_bench_cv)
print('CV XGBC Benchmark Mean:', xgbc_bench_cv.mean())
# CV XGBC Benchmark: [0.999913   0.99996864 0.99994031 0.99992918 0.99994638]
# CV XGBC Benchmark Mean: 0.9999395031292432
# Out:
# [09:57:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:58:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:58:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:59:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:00:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CV XGBC Benchmark: [0.999913   0.99996864 0.99994031 0.99992918 0.99994638]
# CV XGBC Benchmark Mean: 0.9999395031292432

# %% [markdown]
# > #### Creating XGBoost Classifier Benchmark 2 - smote, PF

# %%
xgbc = XGBClassifier(random_state=2021)
smote = SMOTE(random_state=2021)

transformer_xgbc_bench2 = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour']),
    ('poly', PolynomialFeatures(degree=2, include_bias=False), ['x','y','z'])
], remainder='passthrough')

pipe_xgbc_bench2 = imbPipeline([
    ('transformer', transformer_xgbc_bench2),
    ('smote', smote),
    ('xgbc', xgbc)
])

# %%
xgbc_bench2_cv = cross_val_score(pipe_xgbc_bench2, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV XGBC Benchmark:', xgbc_bench2_cv)
print('CV XGBC Benchmark Mean:', xgbc_bench2_cv.mean())
# Out:
# [10:01:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:04:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:07:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:10:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:13:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# CV XGBC Benchmark: [0.99990084 0.99976725 0.99993423 0.99991703 0.99975511]
# CV XGBC Benchmark Mean: 0.9998548940717468

# %% [markdown]
# > #### Creating Ada Boost Classifier Benchmark

# %%
abc = AdaBoostClassifier(random_state=2021)

transformer_abc_bench = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour'])
], remainder='passthrough')

pipe_abc_bench = Pipeline([
    ('transformer', transformer_abc_bench),
    ('abc', abc)
])

# %%
abc_bench_cv = cross_val_score(pipe_abc_bench, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV ABC Benchmark:', abc_bench_cv)
print('CV ABC Benchmark Mean:', abc_bench_cv.mean())
# Out:
# CV ABC Benchmark: [0.99326289 0.99317968 0.99320714 0.99313316 0.99310733]
# CV ABC Benchmark Mean: 0.9931780380522739

# %% [markdown]
# > #### Creating Ada Boost Classifier Benchmark 2 - SMOTE, PF

# %%
abc = AdaBoostClassifier(random_state=2021)

transformer_abc_bench2 = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour']),
    ('poly', PolynomialFeatures(degree=2, include_bias=False), ['x','y','z'])
], remainder='passthrough')

pipe_abc_bench2 = imbPipeline([
    ('transformer', transformer_abc_bench2),
    ('smote', smote),
    ('abc', abc)
])

# %%
abc_bench2_cv = cross_val_score(pipe_abc_bench2, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV ABC Benchmark:', abc_bench2_cv)
print('CV ABC Benchmark Mean:', abc_bench2_cv.mean())
# Out:
# CV ABC Benchmark: [0.96092756 0.95157838 0.95166621 0.95787303 0.95980858]
# CV ABC Benchmark Mean: 0.9563707529565832

# %% [markdown]
# __Threshold adjusment__

# %%
pipe_abc_bench2.fit(X_train_val, y_train_val)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal', OrdinalEncoder(),
#                                                   ['year', 'month', 'day',
#                                                    'hour']),
#                                                  ('poly',
#                                                   PolynomialFeatures(include_bias=False),
#                                                   ['x', 'y', 'z'])])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('abc', AdaBoostClassifier(random_state=2021))])

# %%
ypred_abc_bench2 = pipe_abc_bench2.predict(X_test)
print(classification_report(y_test, ypred_abc_bench2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.77      0.36     19850
#            1       0.99      0.92      0.96    617762
#
#     accuracy                           0.92    637612
#    macro avg       0.62      0.84      0.66    637612
# weighted avg       0.97      0.92      0.94    637612

# %%
confusion_matrix(y_test, ypred_abc_bench2)
# Out:
# array([[ 15194,   4656],
#        [ 48270, 569492]], dtype=int64)

# %%
plot_roc_curve(pipe_abc_bench2, X_test, y_test)

# %% [markdown]
# > #### Creating Logistic Regression Benchmark 1 - smote, PF

# %%
lr_bal = LogisticRegression(class_weight='balanced', solver='liblinear', random_state=2021)

transformer_lr_bench1 = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour']),
    ('poly', PolynomialFeatures(degree=2, include_bias=False), ['x','y','z'])
], remainder='passthrough')

pipe_lr_bench1 = imbPipeline([
    ('transformer', transformer_lr_bench1),
    ('smote', smote),
    ('lr', lr_bal)
])

# %%
lr_bench1_cv = cross_val_score(pipe_lr_bench1, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV LR Benchmark1:', lr_bench1_cv)
print('CV LR Benchmark1 Mean:', lr_bench1_cv.mean())
# Out:
# CV LR Benchmark1: [0.86199671 0.86034088 0.86006769 0.86091804 0.8605258 ]
# CV LR Benchmark1 Mean: 0.8607698236030945

# %% [markdown]
# > #### Creating Naive Bayes GaussianNB Benchmark 1 - smote, PF

# %%
gaus = GaussianNB()

transformer_gaus_bench1 = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour']),
    ('poly', PolynomialFeatures(degree=2, include_bias=False), ['x','y','z'])
], remainder='passthrough')

pipe_gaus_bench1 = imbPipeline([
    ('transformer', transformer_gaus_bench1),
    ('smote', smote),
    ('gaus', gaus)
])

# %%
gaus_bench1_cv = cross_val_score(pipe_gaus_bench1, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV Gaus Benchmark1:', gaus_bench1_cv)
print('CV Gaus Benchmark1 Mean:', gaus_bench1_cv.mean())
# Out:
# CV Gaus Benchmark1: [0.81562579 0.81537054 0.8157392  0.81517946 0.81551128]
# CV Gaus Benchmark1 Mean: 0.8154852554752153

# %% [markdown]
# ## Creating Tuned Models - 1

# %% [markdown]
# > #### DTC Tuned 1 - smote

# %%
dtc = DecisionTreeClassifier(random_state=2021)
smote = SMOTE(random_state=2021)

transformer_dtc_tuned1 = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour'])
], remainder='passthrough')

pipe_dtc_tuned1 = imbPipeline([
    ('transformer', transformer_dtc_tuned1),
    ('smote', smote),
    ('dtc', dtc)
])

# %%
pipe_dtc_tuned1.get_params()
# Out:
# {'memory': None,
#  'steps': [('transformer',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('ordinal', OrdinalEncoder(),
#                                     ['year', 'month', 'day', 'hour'])])),
#   ('smote', SMOTE(random_state=2021)),
#   ('dtc', DecisionTreeClassifier(random_state=2021))],
#  'verbose': False,
#  'transformer': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ordinal', OrdinalEncoder(),
#                                   ['year', 'month', 'day', 'hour'])]),
#  'smote': SMOTE(random_state=2021),
#  'dtc': DecisionTreeClassifier(random_state=2021),
#  'transformer__n_jobs': None,
#  'transformer__remainder': 'passthrough',
#  'transformer__sparse_threshold': 0.3,
#  'transformer__transformer_weights': None,
#  'transformer__transformers': [('ordinal',
#    OrdinalEncoder(),
#    ['year', 'month', 'day', 'hour'])],
#  'transformer__verbose': False,
#  'transformer__ordinal': OrdinalEncoder(),
#  'transformer__ordinal__cols': None,
#  'transformer__ordinal__drop_invariant': False,
#  'transformer__ordinal__handle_missing': 'value',
#  'transformer__ordinal__handle_unknown': 'value',
#  'transformer__ordinal__mapping': None,
#  'transformer__ordinal__return_df': True,
#  'transformer__ordinal__verbose': 0,
#  'smote__k_neighbors': 5,
#  'smote__n_jobs': None,
#  'smote__random_state': 2021,
#  'smote__sampling_strategy': 'auto',
#  'dtc__ccp_alpha': 0.0,
#  'dtc__class_weight': None,
#  'dtc__criterion': 'gini',
#  'dtc__max_depth': None,
#  'dtc__max_features': None,
#  'dtc__max_leaf_nodes': None,
#  'dtc__min_impurity_decrease': 0.0,
#  'dtc__min_impurity_split': None,
#  'dtc__min_samples_leaf': 1,
#  'dtc__min_samples_split': 2,
#  'dtc__min_weight_fraction_leaf': 0.0,
#  'dtc__presort': 'deprecated',
#  'dtc__random_state': 2021,
#  'dtc__splitter': 'best'}

# %%
hyperparam_space_dtc1 = {
    'dtc__criterion':['gini', 'entropy'],
    'dtc__max_depth': [100, 200, 300, None], 
    'dtc__splitter': ['best', 'random'],
    'dtc__max_features': [None, 'auto', 'sqrt', 'log2']
}

gridsearch_dtc1 = GridSearchCV(
    pipe_dtc_tuned1,
    param_grid = hyperparam_space_dtc1,
    cv = skfold,
    scoring = 'f1',
    n_jobs = -1,
    verbose = 1
)

gridsearch_dtc1.fit(X_train_val, y_train_val)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 320 out of 320 | elapsed: 24.8min finished
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=2021, shuffle=True),
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinal',
#                                                                          OrdinalEncoder(),
#                                                                          ['year',
#                                                                           'month',
#                                                                           'day',
#                                                                           'hour'])])),
#                                        ('smote', SMOTE(random_state=2021)),
#                                        ('dtc',
#                                         DecisionTreeClassifier(random_state=2021))]),
#              n_jobs=-1,
#              param_grid={'dtc__criterion': ['gini', 'entropy'],
#                          'dtc__max_depth': [100, 200, 300, None],
#                          'dtc__max_features': [None, 'auto', 'sqrt', 'log2'],
#                          'dtc__splitter': ['best', 'random']},
#              scoring='f1', verbose=1)

# %%
# DTC Tuned1 Model CV Result

gridsearch_dtc1_df = pd.DataFrame(gridsearch_dtc1.cv_results_)
gridsearch_dtc1_df.sort_values('rank_test_score').head(3)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       99.378323      3.694397         0.468906        0.042367
# 34      73.842934      2.810488         0.455503        0.028597
# 35      64.671857      4.253509         0.474107        0.054045
#
#    param_dtc__criterion param_dtc__max_depth param_dtc__max_features  \
# 0                  gini                  100                    None
# 34              entropy                  100                    auto
# 35              entropy                  100                    auto
#
#    param_dtc__splitter                                             params  \
# 0                 best  {'dtc__criterion': 'gini', 'dtc__max_depth': 1...
# 34                best  {'dtc__criterion': 'entropy', 'dtc__max_depth'...
# 35              random  {'dtc__criterion': 'entropy', 'dtc__max_depth'...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0                 1.0                1.0                1.0
# 34                1.0                1.0                1.0
# 35                1.0                1.0                1.0
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.999999                1.0              1.0    4.046867e-07
# 34           0.999999                1.0              1.0    4.046867e-07
# 35           0.999999                1.0              1.0    4.046867e-07
#
#     rank_test_score
# 0                 1
# 34                1
# 35                1

# %%
dtc_tuned1 = gridsearch_dtc1.best_estimator_
dtc_tuned1_cv = cross_val_score(dtc_tuned1, X_train_val, y_train_val, cv=skfold, scoring='f1', n_jobs=-1)

# %%
print("Best DTC Tuned1 Model: ", dtc_tuned1)
print('CV DTC Tuned1:', dtc_tuned1_cv)
print('CV DTC Tuned1 Mean:', dtc_tuned1_cv.mean())
# CV DTC Benchmark1 Mean: 0.9999997976566618
# Out:
# Best DTC Tuned1 Model:  Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal', OrdinalEncoder(),
#                                                   ['year', 'month', 'day',
#                                                    'hour'])])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('dtc',
#                  DecisionTreeClassifier(max_depth=100, random_state=2021))])
# CV DTC Tuned1: [1.         1.         1.         0.99999899 1.        ]
# CV DTC Tuned1 Mean: 0.9999997976566618

# %%
ypred_dtc_tuned1 = dtc_tuned1.predict(X_test)
print(classification_report(y_test, ypred_dtc_tuned1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19850
#            1       1.00      1.00      1.00    617762
#
#     accuracy                           1.00    637612
#    macro avg       1.00      1.00      1.00    637612
# weighted avg       1.00      1.00      1.00    637612

# %% [markdown]
# > #### DTC Tuned 2 - smote, PF

# %%
# dtc = DecisionTreeClassifier(random_state=2021)
# smote = SMOTE()

# transformer_dtc_tuned2 = ColumnTransformer([ 
#     ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour']),
#     ('poly', PolynomialFeatures(degree=2, include_bias=False), ['x','y','z'])
# ], remainder='passthrough')

# pipe_dtc_tuned2 = imbPipeline([
#     ('transformer', transformer_dtc_tuned2),
#     ('smote', smote),
#     ('dtc', dtc)
# ])

# %%
# hyperparam_space_dtc2 = {
#     'dtc__criterion':['gini', 'entropy'],
#     'dtc__splitter': ['best', 'random'],
#     'dtc__max_features': [None, 'auto', 'sqrt', 'log2']
# }

# gridsearch_dtc2 = GridSearchCV(
#     pipe_dtc_tuned2,
#     param_grid = hyperparam_space_dtc2,
#     cv = skfold,
#     scoring = 'f1',
#     n_jobs = -1,
#     verbose = 1
# )

# gridsearch_dtc2.fit(X_train_val, y_train_val)

# %% [markdown]
# > #### XGBC Tuned 1 - smote, PF

# %%
xgbc = XGBClassifier(random_state=2021)
smote = SMOTE()

transformer_xgbc_tuned1 = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour']),
    ('poly', PolynomialFeatures(degree=2, include_bias=False), ['x','y','z'])
], remainder='passthrough')

pipe_xgbc_tuned1 = imbPipeline([
    ('transformer', transformer_xgbc_tuned1),
    ('smote', smote),
    ('xgbc', xgbc)
])

# %%
pipe_xgbc_tuned1.get_params()
# Out:
# {'memory': None,
#  'steps': [('transformer',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('ordinal', OrdinalEncoder(),
#                                     ['year', 'month', 'day', 'hour']),
#                                    ('poly', PolynomialFeatures(include_bias=False),
#                                     ['x', 'y', 'z'])])),
#   ('smote', SMOTE()),
#   ('xgbc',
#    XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#                  colsample_bynode=None, colsample_bytree=None, gamma=None,
#                  gpu_id=None, importance_type='gain', interaction_constraints=None,
#                  learning_rate=None, max_delta_step=None, max_depth=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  random_state=2021, reg_alpha=None, reg_lambda=None,
#                  scale_pos_weight=None, subsample=None, tree_method=None,
#                  validate_parameters=None, verbosity=None))],
#  'verbose': False,
#  'transformer': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ordinal', OrdinalEncoder(),
#                                   ['year', 'month', 'day', 'hour']),
#                                  ('poly', PolynomialFeatures(include_bias=False),
#                                   ['x', 'y', 'z'])]),
#  'smote': SMOTE(),
#  'xgbc': XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#                colsample_bynode=None, colsample_bytree=None, gamma=None,
#                gpu_id=None, importance_type='gain', interaction_constraints=None,
#                learning_rate=None, max_delta_step=None, max_depth=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                random_state=2021, reg_alpha=None, reg_lambda=None,
#                scale_pos_weight=None, subsample=None, tree_method=None,
#                validate_parameters=None, verbosity=None),
#  'transformer__n_jobs': None,
#  'transformer__remainder': 'passthrough',
#  'transformer__sparse_threshold': 0.3,
#  'transformer__transformer_weights': None,
#  'transformer__transformers': [('ordinal',
#    OrdinalEncoder(),
#    ['year', 'month', 'day', 'hour']),
#   ('poly', PolynomialFeatures(include_bias=False), ['x', 'y', 'z'])],
#  'transformer__verbose': False,
#  'transformer__ordinal': OrdinalEncoder(),
#  'transformer__poly': PolynomialFeatures(include_bias=False),
#  'transformer__ordinal__cols': None,
#  'transformer__ordinal__drop_invariant': False,
#  'transformer__ordinal__handle_missing': 'value',
#  'transformer__ordinal__handle_unknown': 'value',
#  'transformer__ordinal__mapping': None,
#  'transformer__ordinal__return_df': True,
#  'transformer__ordinal__verbose': 0,
#  'transformer__poly__degree': 2,
#  'transformer__poly__include_bias': False,
#  'transformer__poly__interaction_only': False,
#  'transformer__poly__order': 'C',
#  'smote__k_neighbors': 5,
#  'smote__n_jobs': None,
#  'smote__random_state': None,
#  'smote__sampling_strategy': 'auto',
#  'xgbc__objective': 'binary:logistic',
#  'xgbc__use_label_encoder': True,
#  'xgbc__base_score': None,
#  'xgbc__booster': None,
#  'xgbc__colsample_bylevel': None,
#  'xgbc__colsample_bynode': None,
#  'xgbc__colsample_bytree': None,
#  'xgbc__gamma': None,
#  'xgbc__gpu_id': None,
#  'xgbc__importance_type': 'gain',
#  'xgbc__interaction_constraints': None,
#  'xgbc__learning_rate': None,
#  'xgbc__max_delta_step': None,
#  'xgbc__max_depth': None,
#  'xgbc__min_child_weight': None,
#  'xgbc__missing': nan,
#  'xgbc__monotone_constraints': None,
#  'xgbc__n_estimators': 100,
#  'xgbc__n_jobs': None,
#  'xgbc__num_parallel_tree': None,
#  'xgbc__random_state': 2021,
#  'xgbc__reg_alpha': None,
#  'xgbc__reg_lambda': None,
#  'xgbc__scale_pos_weight': None,
#  'xgbc__subsample': None,
#  'xgbc__tree_method': None,
#  'xgbc__validate_parameters': None,
#  'xgbc__verbosity': None}

# %%
# hyperparam_space_xgbc1 = {
#     'xgbc__n_estimators': [100, 150, 200],
#     'xgbc__importance_type': ['gain', 'weight', 'cover', 'total_gain', 'total_cover']
# }
# xgbc = XGBClassifier(random_state=2021)
# smote = SMOTE()
# gridsearch_xgbc1 = GridSearchCV(
#     pipe_xgbc_tuned1,
#     param_grid = hyperparam_space_xgbc1,
#     cv = skfold,
#     scoring = 'f1',
#     n_jobs = -1,
#     verbose = 1
# )

# gridsearch_xgbc1.fit(X_train_val, y_train_val)

# %%
# print("Best DTC Tuned1 Model: ", dtc_tuned1)
# print('CV DTC Tuned1:', dtc_tuned1_cv)
# print('CV DTC Tuned1 Mean:', dtc_tuned1_cv.mean())

# %% [markdown]
# > #### Creating Logistic Regression Tuned 1 - smote, PF

# %%
lr_bal_tuned1 = LogisticRegression(class_weight='balanced', solver='liblinear', random_state=2021, C=0.01)
smote2 = SMOTE(k_neighbors=5, random_state=2021)

transformer_lr_tuned1 = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour']),
    ('poly2', PolynomialFeatures(degree=3, include_bias=False), ['x','y','z'])
], remainder='passthrough')

pipe_lr_tuned1 = imbPipeline([
    ('transformer', transformer_lr_tuned1),
    ('smote', smote2),
    ('lr', lr_bal_tuned1)
])

# %%
lr_bal_tuned1_cv = cross_val_score(pipe_lr_tuned1, X_train_val, y_train_val, cv=skfold, scoring='f1')
print('CV LR Benchmark1:', lr_bal_tuned1_cv)
print('CV LR Benchmark1 Mean:', lr_bal_tuned1_cv.mean())
# Out:
# CV LR Benchmark1: [0.86454554 0.86564189 0.86727341 0.86574732 0.86791243]
# CV LR Benchmark1 Mean: 0.8662241175362817

# %%
pipe_lr_tuned1.fit(X_train_val, y_train_val)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal', OrdinalEncoder(),
#                                                   ['year', 'month', 'day',
#                                                    'hour']),
#                                                  ('poly2',
#                                                   PolynomialFeatures(degree=3,
#                                                                      include_bias=False),
#                                                   ['x', 'y', 'z'])])),
#                 ('smote', SMOTE(random_state=2021)),
#                 ('lr',
#                  LogisticRegression(C=0.01, class_weight='balanced',
#                                     random_state=2021, solver='liblinear'))])

# %%
ypred_lr_bal_tuned1 = pipe_lr_tuned1.predict(X_test)
print(classification_report(y_test, ypred_lr_bal_tuned1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.10      0.77      0.17     19850
#            1       0.99      0.77      0.86    617762
#
#     accuracy                           0.77    637612
#    macro avg       0.54      0.77      0.52    637612
# weighted avg       0.96      0.77      0.84    637612

# %%
confusion_matrix(y_test, ypred_lr_bal_tuned1)
# Out:
# array([[ 15200,   4650],
#        [143647, 474115]], dtype=int64)

# %%
plot_roc_curve(pipe_lr_tuned1, X_test, y_test)

# %%
prob_lr_tuned1 = pipe_lr_tuned1.predict_proba(X_test)[:,1]

# %%
fpr_lr_tuned1, tpr_lr_tuned1, threshold_lr_tuned1 = roc_curve(y_test, prob_lr_tuned1)

# %%
roc_lr_tuned1_df = pd.DataFrame({'fpr': fpr_lr_tuned1, 'tpr': tpr_lr_tuned1, 'thr': threshold_lr_tuned1})

# %%
roc_lr_tuned1_df.head(3)
# Out:
#    fpr       tpr       thr
# 0  0.0  0.000000  1.977737
# 1  0.0  0.000159  0.977737
# 2  0.0  0.000238  0.977488

# %%
roc_lr_tuned1_df[(roc_lr_tuned1_df['fpr']>=0.1) & (roc_lr_tuned1_df['fpr']<=0.3) & (roc_lr_tuned1_df['tpr']>=0.7) & (roc_lr_tuned1_df['tpr']<=0.8)]
# Out:
#            fpr       tpr       thr
# 3529  0.218841  0.700001  0.563747
# 3530  0.218841  0.700118  0.563631
# 3531  0.218841  0.700355  0.563232
# 3532  0.218841  0.700380  0.563015
# 3533  0.218841  0.700451  0.562888
# ...        ...       ...       ...
# 3974  0.254307  0.796933  0.467243
# 3975  0.254307  0.797016  0.467006
# 3976  0.254307  0.797318  0.466721
# 3977  0.254307  0.797370  0.466608
# 3978  0.254307  0.797492  0.466546
#
# [450 rows x 3 columns]

# %%
# thr_lr_tuned1 = 0.466190
thr_lr_tuned1 = 0.37
ypred_thr_lr_tuned1 = np.where(pipe_lr_tuned1.predict_proba(X_test)[:,1] > thr_lr_tuned1, 1, 0)
print(classification_report(y_test, ypred_thr_lr_tuned1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.15      0.64      0.25     19850
#            1       0.99      0.88      0.93    617762
#
#     accuracy                           0.88    637612
#    macro avg       0.57      0.76      0.59    637612
# weighted avg       0.96      0.88      0.91    637612

# %%
confusion_matrix(y_test, ypred_thr_lr_tuned1)
# Out:
# array([[ 12744,   7106],
#        [ 71391, 546371]], dtype=int64)

# %% [markdown]
# > #### Creating Naive Bayes GaussianNB Tuned 1 - smote, PF

# %%
gaus = GaussianNB()

transformer_gaus_tuned1 = ColumnTransformer([ 
    ('ordinal', ce.OrdinalEncoder(), ['year', 'month', 'day', 'hour']),
    ('poly', PolynomialFeatures(degree=2, include_bias=False), ['x','y','z'])
], remainder='passthrough')

pipe_gaus_tuned1 = imbPipeline([
    ('transformer', transformer_gaus_tuned1),
    ('smote', smote),
    ('gaus', gaus)
])

# %%
pipe_gaus_tuned1.get_params()
# Out:
# {'memory': None,
#  'steps': [('transformer',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('ordinal', OrdinalEncoder(),
#                                     ['year', 'month', 'day', 'hour']),
#                                    ('poly', PolynomialFeatures(include_bias=False),
#                                     ['x', 'y', 'z'])])),
#   ('smote', SMOTE()),
#   ('gaus', GaussianNB())],
#  'verbose': False,
#  'transformer': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ordinal', OrdinalEncoder(),
#                                   ['year', 'month', 'day', 'hour']),
#                                  ('poly', PolynomialFeatures(include_bias=False),
#                                   ['x', 'y', 'z'])]),
#  'smote': SMOTE(),
#  'gaus': GaussianNB(),
#  'transformer__n_jobs': None,
#  'transformer__remainder': 'passthrough',
#  'transformer__sparse_threshold': 0.3,
#  'transformer__transformer_weights': None,
#  'transformer__transformers': [('ordinal',
#    OrdinalEncoder(),
#    ['year', 'month', 'day', 'hour']),
#   ('poly', PolynomialFeatures(include_bias=False), ['x', 'y', 'z'])],
#  'transformer__verbose': False,
#  'transformer__ordinal': OrdinalEncoder(),
#  'transformer__poly': PolynomialFeatures(include_bias=False),
#  'transformer__ordinal__cols': None,
#  'transformer__ordinal__drop_invariant': False,
#  'transformer__ordinal__handle_missing': 'value',
#  'transformer__ordinal__handle_unknown': 'value',
#  'transformer__ordinal__mapping': None,
#  'transformer__ordinal__return_df': True,
#  'transformer__ordinal__verbose': 0,
#  'transformer__poly__degree': 2,
#  'transformer__poly__include_bias': False,
#  'transformer__poly__interaction_only': False,
#  'transformer__poly__order': 'C',
#  'smote__k_neighbors': 5,
#  'smote__n_jobs': None,
#  'smote__random_state': None,
#  'smote__sampling_strategy': 'auto',
#  'gaus__priors': None,
#  'gaus__var_smoothing': 1e-09}

# %%
hyperparam_space_gaus1 = {
    'transformer__poly__degree':[2, 3],
    'smote__k_neighbors': [3, 5, 7]
}

gridsearch_gaus1 = GridSearchCV(
    pipe_gaus_tuned1,
    param_grid = hyperparam_space_gaus1,
    cv = skfold,
    scoring = 'f1',
    n_jobs = -1,
    verbose = 1
)

gridsearch_gaus1.fit(X_train_val, y_train_val)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 38.8min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 38.8min finished
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=2021, shuffle=True),
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinal',
#                                                                          OrdinalEncoder(),
#                                                                          ['year',
#                                                                           'month',
#                                                                           'day',
#                                                                           'hour']),
#                                                                         ('poly',
#                                                                          PolynomialFeatures(include_bias=False),
#                                                                          ['x',
#                                                                           'y',
#                                                                           'z'])])),
#                                        ('smote', SMOTE()),
#                                        ('gaus', GaussianNB())]),
#              n_jobs=-1,
#              param_grid={'smote__k_neighbors': [3, 5, 7],
#                          'transformer__poly__degree': [2, 3]},
#              scoring='f1', verbose=1)

# %%
# Gaus Tuned1 Model CV Result

gridsearch_gaus1_df = pd.DataFrame(gridsearch_gaus1.cv_results_)
gridsearch_gaus1_df.sort_values('rank_test_score').head(3)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5     482.892269     16.130894        38.111755       11.682065
# 0    1370.343096     20.725713        43.525095       16.846043
# 4     498.848112     13.415313        31.283047       19.302147
#
#   param_smote__k_neighbors param_transformer__poly__degree  \
# 5                        7                               3
# 0                        3                               2
# 4                        7                               2
#
#                                               params  split0_test_score  \
# 5  {'smote__k_neighbors': 7, 'transformer__poly__...           0.815890
# 0  {'smote__k_neighbors': 3, 'transformer__poly__...           0.815626
# 4  {'smote__k_neighbors': 7, 'transformer__poly__...           0.815626
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 5           0.815640           0.815945           0.815449           0.815762
# 0           0.815371           0.815739           0.815179           0.815511
# 4           0.815371           0.815739           0.815179           0.815511
#
#    mean_test_score  std_test_score  rank_test_score
# 5         0.815737        0.000178                1
# 0         0.815485        0.000196                2
# 4         0.815485        0.000196                2

# %%
gaus_tuned1 = gridsearch_gaus1.best_estimator_
gaus_tuned1_cv = cross_val_score(gaus_tuned1, X_train_val, y_train_val, cv=skfold, scoring='f1', n_jobs=-1)

# %%
print("Best Gaus Tuned1 Model: ", gaus_tuned1)
print('CV Gaus Tuned1:', gaus_tuned1_cv)
print('CV Gaus Tuned1 Mean:', gaus_tuned1_cv.mean())
# Out:
# Best Gaus Tuned1 Model:  Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal', OrdinalEncoder(),
#                                                   ['year', 'month', 'day',
#                                                    'hour']),
#                                                  ('poly',
#                                                   PolynomialFeatures(degree=3,
#                                                                      include_bias=False),
#                                                   ['x', 'y', 'z'])])),
#                 ('smote', SMOTE(k_neighbors=7)), ('gaus', GaussianNB())])
# CV Gaus Tuned1: [0.81588972 0.81563968 0.81594455 0.8154493  0.81576184]
# CV Gaus Tuned1 Mean: 0.815737019299252

# %%
ypred_gaus_tuned1 = gaus_tuned1.predict(X_test)
print(classification_report(y_test, ypred_gaus_tuned1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.59      0.11     19850
#            1       0.98      0.70      0.82    617762
#
#     accuracy                           0.69    637612
#    macro avg       0.52      0.64      0.46    637612
# weighted avg       0.95      0.69      0.79    637612

# %%
confusion_matrix(y_test, ypred_gaus_tuned1)
# Out:
# array([[ 11653,   8197],
#        [187232, 430530]], dtype=int64)

# %%
plot_roc_curve(gaus_tuned1, X_test, y_test)

# %%
thr_gaus_tuned1 = 0.6
ypred_thr_gaus_tuned1 = np.where(gaus_tuned1.predict_proba(X_test)[:,1] > thr_gaus_tuned1, 1, 0)
print(classification_report(y_test, ypred_thr_gaus_tuned1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.59      0.11     19850
#            1       0.98      0.70      0.82    617762
#
#     accuracy                           0.69    637612
#    macro avg       0.52      0.64      0.46    637612
# weighted avg       0.95      0.69      0.79    637612

# %%
confusion_matrix(y_test, ypred_thr_gaus_tuned1)
# Out:
# array([[ 11653,   8197],
#        [187232, 430530]], dtype=int64)

# %% [markdown]
# > #### Tes Voting Classifier

# %% [markdown]
# - __Tes VC 1:__

# %%
vc_xgbc_dtc1 = VotingClassifier([('pipexgbcbench2', pipe_xgbc_bench2), ('dtctuned1', dtc_tuned1)], voting='soft')

# %%
vc_xgbc_dtc1.fit(X_train_val, y_train_val)
# Out:
# [15:12:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# VotingClassifier(estimators=[('pipexgbcbench2',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour']),
#                                                                                ('poly',
#                                                                                 PolynomialFeatures(include_bias=False),
#                                                                                 ['x',
#                                                                                  'y',
#                                                                                  'z'])])),
#                                               ('smote',
#                                                SMOTE(random_state=2021)),
#                                               ('xgbc',
#                                                XGBClassifier(base_score=None,
#                                                              booster=None,
#                                                              colsam...
#                                                              subsample=None,
#                                                              tree_method=None,
#                                                              validate_parameters=None,
#                                                              verbosity=None))])),
#                              ('dtctuned1',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour'])])),
#                                               ('smote',
#                                                SMOTE(random_state=2021)),
#                                               ('dtc',
#                                                DecisionTreeClassifier(max_depth=100,
#                                                                       random_state=2021))]))],
#                  voting='soft')

# %%
ypred_vc_xgbc_dtc1 = vc_xgbc_dtc1.predict(X_test)
print(classification_report(y_test, ypred_vc_xgbc_dtc1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19850
#            1       1.00      1.00      1.00    617762
#
#     accuracy                           1.00    637612
#    macro avg       1.00      1.00      1.00    637612
# weighted avg       1.00      1.00      1.00    637612

# %% [markdown]
# - __Tes VC 2:__

# %%
vc_xgbc_dtc_abc1 = VotingClassifier([('pipexgbcbench2', pipe_xgbc_bench2), ('dtctuned1', dtc_tuned1), ('pipeabcbench2', pipe_abc_bench2)], voting='soft')

# %%
vc_xgbc_dtc_abc1.fit(X_train_val, y_train_val)
# Out:
# [15:18:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# VotingClassifier(estimators=[('pipexgbcbench2',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour']),
#                                                                                ('poly',
#                                                                                 PolynomialFeatures(include_bias=False),
#                                                                                 ['x',
#                                                                                  'y',
#                                                                                  'z'])])),
#                                               ('smote',
#                                                SMOTE(random_state=2021)),
#                                               ('xgbc',
#                                                XGBClassifier(base_score=None,
#                                                              booster=None,
#                                                              colsam...
#                                                                       random_state=2021))])),
#                              ('pipeabcbench2',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour']),
#                                                                                ('poly',
#                                                                                 PolynomialFeatures(include_bias=False),
#                                                                                 ['x',
#                                                                                  'y',
#                                                                                  'z'])])),
#                                               ('smote',
#                                                SMOTE(random_state=2021)),
#                                               ('abc',
#                                                AdaBoostClassifier(random_state=2021))]))],
#                  voting='soft')

# %%
ypred_vc_xgbc_dtc_abc1 = vc_xgbc_dtc_abc1.predict(X_test)
print(classification_report(y_test, ypred_vc_xgbc_dtc_abc1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19850
#            1       1.00      1.00      1.00    617762
#
#     accuracy                           1.00    637612
#    macro avg       1.00      1.00      1.00    637612
# weighted avg       1.00      1.00      1.00    637612

# %% [markdown]
# - __Tes VC 3:__

# %%
vc_logit_xgbc_gaus = VotingClassifier([('pipelrtuned1', pipe_lr_tuned1), ('pipexgbcbench2', pipe_xgbc_bench2), ('gaustuned1', gaus_tuned1)], voting='soft')

# %%
vc_logit_xgbc_gaus.fit(X_train_val, y_train_val)
# Out:
# [17:22:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# VotingClassifier(estimators=[('pipelrtuned1',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour']),
#                                                                                ('poly2',
#                                                                                 PolynomialFeatures(degree=3,
#                                                                                                    include_bias=False),
#                                                                                 ['x',
#                                                                                  'y',
#                                                                                  'z'])])),
#                                               ('smote',
#                                                SMOTE(random_state=2021)),
#                                               ('lr',
#                                                LogisticRegression(C=0.01,
#                                                                   class_weight='bal...
#                                                              validate_parameters=None,
#                                                              verbosity=None))])),
#                              ('gaustuned1',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour']),
#                                                                                ('poly',
#                                                                                 PolynomialFeatures(degree=3,
#                                                                                                    include_bias=False),
#                                                                                 ['x',
#                                                                                  'y',
#                                                                                  'z'])])),
#                                               ('smote', SMOTE(k_neighbors=7)),
#                                               ('gaus', GaussianNB())]))],
#                  voting='soft')

# %%
ypred_vc_logit_xgbc_gaus = vc_logit_xgbc_gaus.predict(X_test)
print(classification_report(y_test, ypred_vc_logit_xgbc_gaus))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.15      0.80      0.25     19850
#            1       0.99      0.86      0.92    617762
#
#     accuracy                           0.85    637612
#    macro avg       0.57      0.83      0.59    637612
# weighted avg       0.97      0.85      0.90    637612

# %% [markdown]
# > #### Test Iseng

# %%
samp_df.head()
# Out:
#                        Ids  Labels
# 0  2e69c8bc4_2020-11-29_18   False
# 1  2e6992f24_2020-11-27_18    True
# 2  2e69e8dfc_2020-11-28_15    True
# 3  2e69c47f4_2020-11-26_19    True
# 4  2e68e64d4_2020-11-29_11    True

# %%
test_df.head()
# Out:
#                        Ids
# 0  2e6992a84_2020-11-25_18
# 1  2e68e62f4_2020-11-29_20
# 2  2e68e81a4_2020-11-27_10
# 3   2e69eec04_2020-11-24_7
# 4   2e698e4a4_2020-11-27_8

# %%
# Creating function to convert Ids Table into Proper Independent DF Table for Testing

def ids_to_df(df):
    test_df2 = pd.DataFrame()
    test_df2['s2cell_token'] = df['Ids'].str.split('_').apply(lambda x: x[0])
    test_df2['date'] = df['Ids'].str.split('_').apply(lambda x: x[1])
    test_df2['date'] = test_df2['date'].str.split('-')
    test_df2['hour'] = df['Ids'].str.split('_').apply(lambda x: x[2])
    
    test_df2['year'] = test_df2['date'].apply(lambda x: int(x[0]))
    test_df2['month'] = test_df2['date'].apply(lambda x: int(x[1]))
    test_df2['day'] = test_df2['date'].apply(lambda x: int(x[2]))
    test_df2['hour'] = test_df2['hour'].astype('int')
    
    test_df2['latitude'] = test_df2['s2cell_token'].apply(s2cell.token_to_lat_lon).apply(lambda x: x[0])
    test_df2['longitude'] = test_df2['s2cell_token'].apply(s2cell.token_to_lat_lon).apply(lambda x: x[1])
    
    test_df2['x'] = test_df2['latitude'].apply(cos) * test_df2['longitude'].apply(cos)
    test_df2['y'] = test_df2['latitude'].apply(cos) * test_df2['longitude'].apply(sin)
    test_df2['z'] = test_df2['latitude'].apply(sin)
    
    test_df2 = test_df2[['x', 'y', 'z', 'year', 'month', 'day', 'hour']]
    
    return test_df2

# %%
ids_to_df(test_df)
# Out:
#               x         y         z  year  month  day  hour
# 0      0.994031  0.108207 -0.013921  2020     11   25    18
# 1      0.561143  0.574345 -0.596025  2020     11   29    20
# 2      0.525794  0.591784 -0.611009  2020     11   27    10
# 3      0.996602 -0.021315 -0.079557  2020     11   24     7
# 4      0.972344  0.233176  0.013294  2020     11   27     8
# ...         ...       ...       ...   ...    ...  ...   ...
# 13836  0.520341  0.621773 -0.585357  2020     11   26     5
# 13837  0.953392  0.301451  0.013105  2020     11   24    22
# 13838  0.991486 -0.047556 -0.121218  2020     11   24    10
# 13839  0.951855  0.294791 -0.084091  2020     11   24    18
# 13840  0.989194  0.146264 -0.010091  2020     11   25    19
#
# [13841 rows x 7 columns]

# %% [markdown]
# - __DTC Bench__

# %%
pipe_dtc_bench.fit(X, y)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal', OrdinalEncoder(),
#                                                   ['year', 'month', 'day',
#                                                    'hour'])])),
#                 ('dtc', DecisionTreeClassifier(random_state=2021))])

# %%
y_pred_dtc_bench = pipe_dtc_bench.predict(ids_to_df(test_df))

# %%
result_dtc_bench = test_df.copy()
result_dtc_bench['Labels'] = y_pred_dtc_bench
result_dtc_bench['Labels'] = np.where(result_dtc_bench['Labels']==1, True, False)

# %%
result_dtc_bench
# Out:
#                            Ids  Labels
# 0      2e6992a84_2020-11-25_18    True
# 1      2e68e62f4_2020-11-29_20    True
# 2      2e68e81a4_2020-11-27_10    True
# 3       2e69eec04_2020-11-24_7    True
# 4       2e698e4a4_2020-11-27_8    True
# ...                        ...     ...
# 13836   2e68dd414_2020-11-26_5    True
# 13837  2e698541c_2020-11-24_22    True
# 13838  2e69e8e0c_2020-11-24_10    True
# 13839  2e699a1cc_2020-11-24_18   False
# 13840  2e698d804_2020-11-25_19    True
#
# [13841 rows x 2 columns]

# %% [markdown]
# - __vc_xgbc_dtc_abc1 (ENSAMBLE)__

# %%
vc_xgbc_dtc_abc1.fit(X, y)
# Out:
# [15:32:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# VotingClassifier(estimators=[('pipexgbcbench2',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour']),
#                                                                                ('poly',
#                                                                                 PolynomialFeatures(include_bias=False),
#                                                                                 ['x',
#                                                                                  'y',
#                                                                                  'z'])])),
#                                               ('smote',
#                                                SMOTE(random_state=2021)),
#                                               ('xgbc',
#                                                XGBClassifier(base_score=None,
#                                                              booster=None,
#                                                              colsam...
#                                                                       random_state=2021))])),
#                              ('pipeabcbench2',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour']),
#                                                                                ('poly',
#                                                                                 PolynomialFeatures(include_bias=False),
#                                                                                 ['x',
#                                                                                  'y',
#                                                                                  'z'])])),
#                                               ('smote',
#                                                SMOTE(random_state=2021)),
#                                               ('abc',
#                                                AdaBoostClassifier(random_state=2021))]))],
#                  voting='soft')

# %%
y_pred_vc_xgbc_dtc_abc1 = vc_xgbc_dtc_abc1.predict(ids_to_df(test_df))

# %%
result_vc_xgbc_dtc_abc1 = test_df.copy()
result_vc_xgbc_dtc_abc1['Labels'] = y_pred_vc_xgbc_dtc_abc1
result_vc_xgbc_dtc_abc1['Labels'] = np.where(result_vc_xgbc_dtc_abc1['Labels']==1, True, False)

# %%
result_vc_xgbc_dtc_abc1
# Out:
#                            Ids  Labels
# 0      2e6992a84_2020-11-25_18    True
# 1      2e68e62f4_2020-11-29_20    True
# 2      2e68e81a4_2020-11-27_10    True
# 3       2e69eec04_2020-11-24_7    True
# 4       2e698e4a4_2020-11-27_8    True
# ...                        ...     ...
# 13836   2e68dd414_2020-11-26_5    True
# 13837  2e698541c_2020-11-24_22    True
# 13838  2e69e8e0c_2020-11-24_10    True
# 13839  2e699a1cc_2020-11-24_18    True
# 13840  2e698d804_2020-11-25_19    True
#
# [13841 rows x 2 columns]

# %%
# result_vc_xgbc_dtc_abc1.to_csv('TruePositive_2.csv', index=False)

# %% [markdown]
# - __vc_logit_xgbc_gaus (ENSAMBLE)__

# %%
vc_logit_xgbc_gaus.fit(X, y)
# Out:
# [18:18:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# VotingClassifier(estimators=[('pipelrtuned1',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour']),
#                                                                                ('poly2',
#                                                                                 PolynomialFeatures(degree=3,
#                                                                                                    include_bias=False),
#                                                                                 ['x',
#                                                                                  'y',
#                                                                                  'z'])])),
#                                               ('smote',
#                                                SMOTE(random_state=2021)),
#                                               ('lr',
#                                                LogisticRegression(C=0.01,
#                                                                   class_weight='bal...
#                                                              validate_parameters=None,
#                                                              verbosity=None))])),
#                              ('gaustuned1',
#                               Pipeline(steps=[('transformer',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('ordinal',
#                                                                                 OrdinalEncoder(),
#                                                                                 ['year',
#                                                                                  'month',
#                                                                                  'day',
#                                                                                  'hour']),
#                                                                                ('poly',
#                                                                                 PolynomialFeatures(degree=3,
#                                                                                                    include_bias=False),
#                                                                                 ['x',
#                                                                                  'y',
#                                                                                  'z'])])),
#                                               ('smote', SMOTE(k_neighbors=7)),
#                                               ('gaus', GaussianNB())]))],
#                  voting='soft')

# %%
y_pred_vc_logit_xgbc_gaus = vc_logit_xgbc_gaus.predict(ids_to_df(test_df))

# %%
result_vc_logit_xgbc_gaus = test_df.copy()
result_vc_logit_xgbc_gaus['Labels'] = y_pred_vc_logit_xgbc_gaus
result_vc_logit_xgbc_gaus['Labels'] = np.where(result_vc_logit_xgbc_gaus['Labels']==1, True, False)

# %%
result_vc_logit_xgbc_gaus.to_csv('TruePositive_3.csv', index=False)

# %% [markdown]
# > #### Test Iseng 2 - REMOVING 'YEAR'

# %%
X2 = data_ml[['x', 'y', 'z', 'month', 'day', 'hour']]
y2 = data_ml['Labels']
