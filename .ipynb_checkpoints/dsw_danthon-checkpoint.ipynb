# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV, train_test_split

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from imblearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report

import datetime as dt

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
train = pd.read_csv('data_train.csv')
alerts = pd.read_csv('alerts.csv')
irreg = pd.read_csv('irregularities.csv')

# %% [markdown]
# # Preprocessing: Alerts

# %%
train.head()
# Out:
#                        Ids  Labels
# 0  2e69e9384_2020-10-06_13    True
# 1  2e6992c7c_2020-10-02_17    True
# 2  2e69ef474_2020-09-13_19    True
# 3  2e69c5fd4_2020-10-10_15    True
# 4  2e6992134_2020-09-12_11    True

# %%
train.tail()
# Out:
#                            Ids  Labels
# 71331  2e69eea5c_2020-11-09_10   False
# 71332  2e69c5944_2020-10-27_12    True
# 71333  2e69f2cd4_2020-11-07_14    True
# 71334   2e68e64e4_2020-09-23_9   False
# 71335  2e68e6084_2020-10-18_12   False

# %%
alerts.head()
# Out:
#           id     pub_millis              s2id_15 s2token_15  road_type  \
# 0  177876895  1603331480000  3344466888162803712  2e69eeea4          1
# 1  179156987  1604487892000  3344463130066419712  2e69eb7f4          6
# 2  181688703  1605666614000  3344367648648462336  2e6994a84          7
# 3  173055165  1601895721000  3344374458319110144  2e699ad9c          2
# 4  173802602  1602464394000  3344466709921660928  2e69eec0c          2
#
#                 street      city  magvar  reliability  report_description  \
# 0                  NaN     Depok       0            9                 NaN
# 1  N8 Jalan Raya Bogor     Depok     170            7                 NaN
# 2                  NaN    Bekasi       0            8                 NaN
# 3   Flyover Tegal Gede  Cikarang     319           10                 NaN
# 4      Tanjakan Kembar     Depok     310            5                 NaN
#
#    report_rating  confidence           type                  subtype  \
# 0              0           1    ROAD_CLOSED        ROAD_CLOSED_EVENT
# 1              1           1            JAM        JAM_HEAVY_TRAFFIC
# 2              0           1    ROAD_CLOSED        ROAD_CLOSED_EVENT
# 3              5           0  WEATHERHAZARD  HAZARD_ON_ROAD_POT_HOLE
# 4              3           0            JAM        JAM_HEAVY_TRAFFIC
#
#    report_by_municipality_user  n_thumbs_up   longitude  latitude
# 0                          NaN          NaN  106.788545 -6.359846
# 1                          NaN          0.0  106.867141 -6.383855
# 2                          NaN          NaN  106.921974 -6.379087
# 3                          NaN          NaN  107.143656 -6.300441
# 4                          NaN          NaN  106.793950 -6.365677

# %% [markdown]
# ## Change millisecond to Date and Time

# %%
alerts['pub_date'] = [dt.datetime.fromtimestamp(i/1000.0) for i in alerts['pub_millis']]
alerts['pub_date'].head()
# Out:
# 0   2020-10-22 08:51:20
# 1   2020-11-04 18:04:52
# 2   2020-11-18 09:30:14
# 3   2020-10-05 18:02:01
# 4   2020-10-12 07:59:54
# Name: pub_date, dtype: datetime64[ns]

# %%
alerts.head()
# Out:
#           id     pub_millis              s2id_15 s2token_15  road_type  \
# 0  177876895  1603331480000  3344466888162803712  2e69eeea4          1
# 1  179156987  1604487892000  3344463130066419712  2e69eb7f4          6
# 2  181688703  1605666614000  3344367648648462336  2e6994a84          7
# 3  173055165  1601895721000  3344374458319110144  2e699ad9c          2
# 4  173802602  1602464394000  3344466709921660928  2e69eec0c          2
#
#                 street      city  magvar  reliability  report_description  \
# 0                  NaN     Depok       0            9                 NaN
# 1  N8 Jalan Raya Bogor     Depok     170            7                 NaN
# 2                  NaN    Bekasi       0            8                 NaN
# 3   Flyover Tegal Gede  Cikarang     319           10                 NaN
# 4      Tanjakan Kembar     Depok     310            5                 NaN
#
#    report_rating  confidence           type                  subtype  \
# 0              0           1    ROAD_CLOSED        ROAD_CLOSED_EVENT
# 1              1           1            JAM        JAM_HEAVY_TRAFFIC
# 2              0           1    ROAD_CLOSED        ROAD_CLOSED_EVENT
# 3              5           0  WEATHERHAZARD  HAZARD_ON_ROAD_POT_HOLE
# 4              3           0            JAM        JAM_HEAVY_TRAFFIC
#
#    report_by_municipality_user  n_thumbs_up   longitude  latitude  \
# 0                          NaN          NaN  106.788545 -6.359846
# 1                          NaN          0.0  106.867141 -6.383855
# 2                          NaN          NaN  106.921974 -6.379087
# 3                          NaN          NaN  107.143656 -6.300441
# 4                          NaN          NaN  106.793950 -6.365677
#
#              pub_date
# 0 2020-10-22 08:51:20
# 1 2020-11-04 18:04:52
# 2 2020-11-18 09:30:14
# 3 2020-10-05 18:02:01
# 4 2020-10-12 07:59:54

# %%
alerts['pub_date'].head(3)
# Out:
# 0   2020-10-22 08:51:20
# 1   2020-11-04 18:04:52
# 2   2020-11-18 09:30:14
# Name: pub_date, dtype: datetime64[ns]

# %% [markdown]
# ## Split `dates` and `hour` into Two New Columns

# %%
alerts['dates'] = [i.strftime('%Y-%m-%d') for i in alerts['pub_date']]

# %%
alerts['hour'] = [str(i.hour) for i in alerts['pub_date']]

# %%
alerts.head()
# Out:
#           id     pub_millis              s2id_15 s2token_15  road_type  \
# 0  177876895  1603331480000  3344466888162803712  2e69eeea4          1
# 1  179156987  1604487892000  3344463130066419712  2e69eb7f4          6
# 2  181688703  1605666614000  3344367648648462336  2e6994a84          7
# 3  173055165  1601895721000  3344374458319110144  2e699ad9c          2
# 4  173802602  1602464394000  3344466709921660928  2e69eec0c          2
#
#                 street      city  magvar  reliability  report_description  \
# 0                  NaN     Depok       0            9                 NaN
# 1  N8 Jalan Raya Bogor     Depok     170            7                 NaN
# 2                  NaN    Bekasi       0            8                 NaN
# 3   Flyover Tegal Gede  Cikarang     319           10                 NaN
# 4      Tanjakan Kembar     Depok     310            5                 NaN
#
#    report_rating  confidence           type                  subtype  \
# 0              0           1    ROAD_CLOSED        ROAD_CLOSED_EVENT
# 1              1           1            JAM        JAM_HEAVY_TRAFFIC
# 2              0           1    ROAD_CLOSED        ROAD_CLOSED_EVENT
# 3              5           0  WEATHERHAZARD  HAZARD_ON_ROAD_POT_HOLE
# 4              3           0            JAM        JAM_HEAVY_TRAFFIC
#
#    report_by_municipality_user  n_thumbs_up   longitude  latitude  \
# 0                          NaN          NaN  106.788545 -6.359846
# 1                          NaN          0.0  106.867141 -6.383855
# 2                          NaN          NaN  106.921974 -6.379087
# 3                          NaN          NaN  107.143656 -6.300441
# 4                          NaN          NaN  106.793950 -6.365677
#
#              pub_date       dates hour
# 0 2020-10-22 08:51:20  2020-10-22    8
# 1 2020-11-04 18:04:52  2020-11-04   18
# 2 2020-11-18 09:30:14  2020-11-18    9
# 3 2020-10-05 18:02:01  2020-10-05   18
# 4 2020-10-12 07:59:54  2020-10-12    7

# %% [markdown]
# ## Combine `s2token_15`, `dates` and `hour` into ids for Merging with Train DF

# %%
alerts['Ids'] = alerts['s2token_15']+'_'+alerts['dates']+'_'+alerts['hour']

# %%
alerts.head()
# Out:
#           id     pub_millis              s2id_15 s2token_15  road_type  \
# 0  177876895  1603331480000  3344466888162803712  2e69eeea4          1
# 1  179156987  1604487892000  3344463130066419712  2e69eb7f4          6
# 2  181688703  1605666614000  3344367648648462336  2e6994a84          7
# 3  173055165  1601895721000  3344374458319110144  2e699ad9c          2
# 4  173802602  1602464394000  3344466709921660928  2e69eec0c          2
#
#                 street      city  magvar  reliability  report_description  \
# 0                  NaN     Depok       0            9                 NaN
# 1  N8 Jalan Raya Bogor     Depok     170            7                 NaN
# 2                  NaN    Bekasi       0            8                 NaN
# 3   Flyover Tegal Gede  Cikarang     319           10                 NaN
# 4      Tanjakan Kembar     Depok     310            5                 NaN
#
#    report_rating  confidence           type                  subtype  \
# 0              0           1    ROAD_CLOSED        ROAD_CLOSED_EVENT
# 1              1           1            JAM        JAM_HEAVY_TRAFFIC
# 2              0           1    ROAD_CLOSED        ROAD_CLOSED_EVENT
# 3              5           0  WEATHERHAZARD  HAZARD_ON_ROAD_POT_HOLE
# 4              3           0            JAM        JAM_HEAVY_TRAFFIC
#
#    report_by_municipality_user  n_thumbs_up   longitude  latitude  \
# 0                          NaN          NaN  106.788545 -6.359846
# 1                          NaN          0.0  106.867141 -6.383855
# 2                          NaN          NaN  106.921974 -6.379087
# 3                          NaN          NaN  107.143656 -6.300441
# 4                          NaN          NaN  106.793950 -6.365677
#
#              pub_date       dates hour                      Ids
# 0 2020-10-22 08:51:20  2020-10-22    8   2e69eeea4_2020-10-22_8
# 1 2020-11-04 18:04:52  2020-11-04   18  2e69eb7f4_2020-11-04_18
# 2 2020-11-18 09:30:14  2020-11-18    9   2e6994a84_2020-11-18_9
# 3 2020-10-05 18:02:01  2020-10-05   18  2e699ad9c_2020-10-05_18
# 4 2020-10-12 07:59:54  2020-10-12    7   2e69eec0c_2020-10-12_7

# %% [markdown]
# ## Make Function to Simplifies The Proccess

# %%
def make_ids(df, col_millis, col_token):
    df['pub_date'] = [dt.datetime.fromtimestamp(i/1000.0) for i in df[col_millis]]
    df['dates'] = [i.strftime('%Y-%m-%d') for i in df['pub_date']]
    df['hour'] = [str(i.hour) for i in df['pub_date']]
    df['Ids'] = df[col_token]+'_'+df['dates']+'_'+df['hour']
    return df

# %% [markdown]
# # Preprocessing `irregularities`

# %%
irreg.head()
# Out:
#          id  detection_date_millis  update_date_millis  \
# 0  12868069          1604733149024       1604735467276
# 1  12420463          1599906813144       1599909295834
# 2  12497533          1601728355356       1601734996933
# 3  12536831          1602312860279       1602315706305
# 4  12327151          1598956623240       1598957378934
#
#                    street            city is_highway  \
# 0       Jatiwaringin Raya          Bekasi          t
# 1           Putri Tunggal           Depok          f
# 2          Ir Haji Juanda         Bandung          f
# 3      KH Muchtar Tabrani          Bekasi          f
# 4  N1 Pangeran Diponegoro  Tambun Selatan          t
#
#                                                 line          s2id_center  \
# 0  {"line": [{"x": 106.91014, "y": -6.258107}, {"...  3344471185277583360
# 1  {"line": [{"x": 106.887821, "y": -6.377016}, {...  3344462996922433536
# 2  {"line": [{"x": 107.618629, "y": -6.87556}, {"...  3344176694402482176
# 3  {"line": [{"x": 107.002934, "y": -6.216088}, {...  3344358143885836288
# 4  {"line": [{"x": 107.035652, "y": -6.255471}, {...  3344360723013697536
#
#   s2token_center  speed  regular_speed  delay_seconds  seconds  length  trend  \
# 0      2e69f2d2c  13.03          17.15            299      432    1566      0
# 1      2e69eb604   6.56          18.00            399      539     984      0
# 2      2e68e6fc4   3.36          19.65           1185     1294    1212      1
# 3      2e698c034   4.36           8.04            467      543     659     -1
# 4      2e698e5bc   4.74          16.71            423      474     625      0
#
#     type  severity  jam_level  drivers_count  alerts_count  n_thumbs_up
# 0  Small         5          3             13             0            0
# 1  Small         5          3              5             0            0
# 2  Large         5          4             21             2            0
# 3  Small         5          4              3             0            0
# 4  Small         5          4             11             0            0

# %%
irreg_up = make_ids(irreg, 'update_date_millis', 's2token_center')

# %%
irreg_det = make_ids(irreg, 'detection_date_millis', 's2token_center')

# %% [markdown]
# # Joining

# %%
test = pd.read_csv('data_test.csv')
test.shape
# Out:
# (13841, 1)

# %%
train.shape
# Out:
# (71336, 2)

# %%
alerts.shape
# Out:
# (7800662, 22)

# %%
display(train.head(1))
display(test.head(1))
display(alerts.head(1))
display(irreg_up.head(1))
# Out:
#                        Ids  Labels
# 0  2e69e9384_2020-10-06_13    True
#                        Ids
# 0  2e6992a84_2020-11-25_18
#           id     pub_millis              s2id_15 s2token_15  road_type street  \
# 0  177876895  1603331480000  3344466888162803712  2e69eeea4          1    NaN
#
#     city  magvar  reliability  report_description  report_rating  confidence  \
# 0  Depok       0            9                 NaN              0           1
#
#           type            subtype  report_by_municipality_user  n_thumbs_up  \
# 0  ROAD_CLOSED  ROAD_CLOSED_EVENT                          NaN          NaN
#
#     longitude  latitude            pub_date       dates hour  \
# 0  106.788545 -6.359846 2020-10-22 08:51:20  2020-10-22    8
#
#                       Ids
# 0  2e69eeea4_2020-10-22_8
#          id  detection_date_millis  update_date_millis             street  \
# 0  12868069          1604733149024       1604735467276  Jatiwaringin Raya
#
#      city is_highway                                               line  \
# 0  Bekasi          t  {"line": [{"x": 106.91014, "y": -6.258107}, {"...
#
#            s2id_center s2token_center  speed  regular_speed  delay_seconds  \
# 0  3344471185277583360      2e69f2d2c  13.03          17.15            299
#
#    seconds  length  trend   type  severity  jam_level  drivers_count  \
# 0      432    1566      0  Small         5          3             13
#
#    alerts_count  n_thumbs_up                pub_date       dates hour  \
# 0             0            0 2020-11-07 14:12:29.024  2020-11-07   14
#
#                        Ids
# 0  2e69f2d2c_2020-11-07_14

# %%
merge_train_alerts = pd.merge(train, alerts, on=['Ids'])

# %%
data = pd.merge(merge_train_alerts, irreg_up, on=['Ids'])

# %%
data.shape
# Out:
# (3707448, 47)

# %%
data.head()
# Out:
#                        Ids  Labels       id_x     pub_millis  \
# 0  2e698e484_2020-09-25_10    True  170560751  1601003424000
# 1  2e698e484_2020-09-25_10    True  170560751  1601003424000
# 2  2e698e484_2020-09-25_10    True  170560751  1601003424000
# 3  2e698e484_2020-09-25_10    True  170560751  1601003424000
# 4  2e698e484_2020-09-25_10    True  170560751  1601003424000
#
#                s2id_15 s2token_15  road_type      street_x          city_x  \
# 0  3344360639261835264  2e698e484          2  Lambang Jaya  Tambun Selatan
# 1  3344360639261835264  2e698e484          2  Lambang Jaya  Tambun Selatan
# 2  3344360639261835264  2e698e484          2  Lambang Jaya  Tambun Selatan
# 3  3344360639261835264  2e698e484          2  Lambang Jaya  Tambun Selatan
# 4  3344360639261835264  2e698e484          2  Lambang Jaya  Tambun Selatan
#
#    magvar  reliability  report_description  report_rating  confidence type_x  \
# 0     109            6                 NaN              2           0    JAM
# 1     109            6                 NaN              2           0    JAM
# 2     109            6                 NaN              2           0    JAM
# 3     109            6                 NaN              2           0    JAM
# 4     109            6                 NaN              2           0    JAM
#
#                    subtype  report_by_municipality_user  n_thumbs_up_x  \
# 0  JAM_STAND_STILL_TRAFFIC                          NaN            0.0
# 1  JAM_STAND_STILL_TRAFFIC                          NaN            0.0
# 2  JAM_STAND_STILL_TRAFFIC                          NaN            0.0
# 3  JAM_STAND_STILL_TRAFFIC                          NaN            0.0
# 4  JAM_STAND_STILL_TRAFFIC                          NaN            0.0
#
#     longitude  latitude          pub_date_x     dates_x hour_x      id_y  \
# 0  107.044226 -6.270431 2020-09-25 10:10:24  2020-09-25     10  12454338
# 1  107.044226 -6.270431 2020-09-25 10:10:24  2020-09-25     10  12454321
# 2  107.044226 -6.270431 2020-09-25 10:10:24  2020-09-25     10  12454341
# 3  107.044226 -6.270431 2020-09-25 10:10:24  2020-09-25     10  12454315
# 4  107.044226 -6.270431 2020-09-25 10:10:24  2020-09-25     10  12454330
#
#    detection_date_millis  update_date_millis      street_y          city_y  \
# 0          1601005939233       1601008279450  Lambang Jaya  Tambun Selatan
# 1          1601005939233       1601007955894  Lambang Jaya  Tambun Selatan
# 2          1601005939233       1601008357781  Lambang Jaya  Tambun Selatan
# 3          1601005939233       1601007798478  Lambang Jaya  Tambun Selatan
# 4          1601005939233       1601008114231  Lambang Jaya  Tambun Selatan
#
#   is_highway                                               line  \
# 0          f  {"line": [{"x": 107.040272, "y": -6.268992}, {...
# 1          f  {"line": [{"x": 107.03547, "y": -6.267191}, {"...
# 2          f  {"line": [{"x": 107.040272, "y": -6.268992}, {...
# 3          f  {"line": [{"x": 107.03547, "y": -6.267191}, {"...
# 4          f  {"line": [{"x": 107.040272, "y": -6.268992}, {...
#
#            s2id_center s2token_center  speed  regular_speed  delay_seconds  \
# 0  3344360639261835264      2e698e484   6.75          25.63            362
# 1  3344360639261835264      2e698e484   8.01          30.29            500
# 2  3344360639261835264      2e698e484   6.78          25.61            360
# 3  3344360639261835264      2e698e484   9.14          30.45            423
# 4  3344360639261835264      2e698e484   8.12          26.33            288
#
#    seconds  length  trend  type_y  severity  jam_level  drivers_count  \
# 0      440     827      1   Small         5          4              7
# 1      625    1394      1  Medium         5          4              7
# 2      438     827      0   Small         5          4              6
# 3      548    1394     -1   Small         5          3              7
# 4      366     827      0   Small         5          4              7
#
#    alerts_count  n_thumbs_up_y              pub_date_y     dates_y hour_y
# 0             0              0 2020-09-25 10:52:19.233  2020-09-25     10
# 1             0              0 2020-09-25 10:52:19.233  2020-09-25     10
# 2             0              0 2020-09-25 10:52:19.233  2020-09-25     10
# 3             0              0 2020-09-25 10:52:19.233  2020-09-25     10
# 4             0              0 2020-09-25 10:52:19.233  2020-09-25     10

# %% [markdown]
# ## EDA

# %%
data.head(1)
# Out:
#                        Ids  Labels       id_x     pub_millis  \
# 0  2e698e484_2020-09-25_10    True  170560751  1601003424000
#
#                s2id_15 s2token_15  road_type      street_x          city_x  \
# 0  3344360639261835264  2e698e484          2  Lambang Jaya  Tambun Selatan
#
#    magvar  reliability  report_description  report_rating  confidence type_x  \
# 0     109            6                 NaN              2           0    JAM
#
#                    subtype  report_by_municipality_user  n_thumbs_up_x  \
# 0  JAM_STAND_STILL_TRAFFIC                          NaN            0.0
#
#     longitude  latitude          pub_date_x     dates_x hour_x      id_y  \
# 0  107.044226 -6.270431 2020-09-25 10:10:24  2020-09-25     10  12454338
#
#    detection_date_millis  update_date_millis      street_y          city_y  \
# 0          1601005939233       1601008279450  Lambang Jaya  Tambun Selatan
#
#   is_highway                                               line  \
# 0          f  {"line": [{"x": 107.040272, "y": -6.268992}, {...
#
#            s2id_center s2token_center  speed  regular_speed  delay_seconds  \
# 0  3344360639261835264      2e698e484   6.75          25.63            362
#
#    seconds  length  trend type_y  severity  jam_level  drivers_count  \
# 0      440     827      1  Small         5          4              7
#
#    alerts_count  n_thumbs_up_y              pub_date_y     dates_y hour_y
# 0             0              0 2020-09-25 10:52:19.233  2020-09-25     10

# %%
(data.isna().sum()/len(data)*100).sort_values(ascending=False).head(10)
# Out:
# report_description             100.000000
# report_by_municipality_user    100.000000
# n_thumbs_up_x                   76.760591
# subtype                          4.640524
# street_x                         3.114649
# street_y                         0.900458
# report_rating                    0.000000
# pub_date_x                       0.000000
# latitude                         0.000000
# longitude                        0.000000
# dtype: float64

# %% [markdown]
# **Note**: We can delete columns that contain a lot of NaN values. The following is also the column that has no relationship with the target variable.

# %%
data.describe()
# Out:
#                id_x    pub_millis       s2id_15     road_type        magvar  \
# count  3.707448e+06  3.707448e+06  3.707448e+06  3.707448e+06  3.707448e+06
# mean   1.764340e+08  1.603416e+12  3.344330e+18  4.891745e+00  1.625304e+02
# std    3.912717e+06  1.660056e+09  1.148454e+14  2.581285e+00  1.181746e+02
# min    1.663211e+08  1.598920e+12  3.344137e+18  1.000000e+00  0.000000e+00
# 25%    1.735164e+08  1.602319e+12  3.344178e+18  2.000000e+00  5.400000e+01
# 50%    1.776130e+08  1.603854e+12  3.344361e+18  6.000000e+00  1.660000e+02
# 75%    1.794791e+08  1.604660e+12  3.344425e+18  7.000000e+00  2.670000e+02
# max    1.821552e+08  1.606042e+12  3.344471e+18  2.200000e+01  3.590000e+02
#
#         reliability  report_description  report_rating    confidence  \
# count  3.707448e+06                 0.0   3.707448e+06  3.707448e+06
# mean   5.642938e+00                 NaN   1.759216e+00  1.692776e-01
# std    1.024156e+00                 NaN   1.389461e+00  5.446661e-01
# min    5.000000e+00                 NaN   0.000000e+00  0.000000e+00
# 25%    5.000000e+00                 NaN   1.000000e+00  0.000000e+00
# 50%    5.000000e+00                 NaN   2.000000e+00  0.000000e+00
# 75%    6.000000e+00                 NaN   3.000000e+00  0.000000e+00
# max    1.000000e+01                 NaN   5.000000e+00  5.000000e+00
#
#        report_by_municipality_user  n_thumbs_up_x     longitude      latitude  \
# count                          0.0       861589.0  3.707448e+06  3.707448e+06
# mean                           NaN            0.0  1.071354e+02 -6.540876e+00
# std                            NaN            0.0  3.473850e-01  2.697997e-01
# min                            NaN            0.0  1.067219e+02 -6.961995e+00
# 25%                            NaN            0.0  1.069011e+02 -6.880992e+00
# 50%                            NaN            0.0  1.069605e+02 -6.395953e+00
# 75%                            NaN            0.0  1.076023e+02 -6.308303e+00
# max                            NaN            0.0  1.077158e+02 -6.160888e+00
#
#                id_y  detection_date_millis  update_date_millis   s2id_center  \
# count  3.707448e+06           3.707448e+06        3.707448e+06  3.707448e+06
# mean   1.269784e+07           1.603416e+12        1.603419e+12  3.344330e+18
# std    1.815409e+05           1.659972e+09        1.660245e+09  1.148454e+14
# min    1.232388e+07           1.598920e+12        1.598921e+12  3.344137e+18
# 25%    1.254033e+07           1.602319e+12        1.602321e+12  3.344178e+18
# 50%    1.268745e+07           1.603857e+12        1.603859e+12  3.344361e+18
# 75%    1.285582e+07           1.604661e+12        1.604663e+12  3.344425e+18
# max    1.306029e+07           1.606042e+12        1.606048e+12  3.344471e+18
#
#               speed  regular_speed  delay_seconds       seconds        length  \
# count  3.707448e+06   3.707448e+06   3.707448e+06  3.707448e+06  3.707448e+06
# mean   6.366959e+00   2.078335e+01   6.611974e+02  7.817901e+02  1.265223e+03
# std    3.198366e+00   1.068939e+01   3.823192e+02  4.053880e+02  7.400426e+02
# min    5.700000e-01   3.750000e+00   6.900000e+01  1.200000e+02  5.000000e+02
# 25%    4.000000e+00   1.489000e+01   4.450000e+02  5.380000e+02  7.160000e+02
# 50%    5.650000e+00   1.921000e+01   5.830000e+02  6.920000e+02  1.027000e+03
# 75%    7.960000e+00   2.487000e+01   7.750000e+02  9.250000e+02  1.542000e+03
# max    2.865000e+01   1.832770e+03   7.053000e+03  5.217000e+03  6.191000e+03
#
#               trend   severity     jam_level  drivers_count  alerts_count  \
# count  3.707448e+06  3707448.0  3.707448e+06   3.707448e+06  3.707448e+06
# mean  -1.781204e-01        5.0  3.759645e+00   1.097375e+01  9.342653e-01
# std    7.858336e-01        0.0  4.440751e-01   8.998078e+00  1.438933e+00
# min   -1.000000e+00        5.0  1.000000e+00   1.000000e+00  0.000000e+00
# 25%   -1.000000e+00        5.0  4.000000e+00   5.000000e+00  0.000000e+00
# 50%    0.000000e+00        5.0  4.000000e+00   9.000000e+00  0.000000e+00
# 75%    0.000000e+00        5.0  4.000000e+00   1.400000e+01  1.000000e+00
# max    1.000000e+00        5.0  4.000000e+00   1.000000e+02  1.500000e+01
#
#        n_thumbs_up_y
# count   3.707448e+06
# mean    3.293530e-01
# std     1.058309e+00
# min     0.000000e+00
# 25%     0.000000e+00
# 50%     0.000000e+00
# 75%     0.000000e+00
# max     2.500000e+01

# %%
# !pip install s2cell

# %%
import s2cell

# %%
coor = [s2cell.token_to_lat_lon(i) for i in data['s2token_15']]

# %%
coor = np.array(coor)

# %%
data['lat'] = coor[:,0]
data['lon'] = coor[:,1]

# %%
data.head(1)
# Out:
#                        Ids  Labels       id_x     pub_millis  \
# 0  2e698e484_2020-09-25_10    True  170560751  1601003424000
#
#                s2id_15 s2token_15  road_type      street_x          city_x  \
# 0  3344360639261835264  2e698e484          2  Lambang Jaya  Tambun Selatan
#
#    magvar  reliability  report_description  report_rating  confidence type_x  \
# 0     109            6                 NaN              2           0    JAM
#
#                    subtype  report_by_municipality_user  n_thumbs_up_x  \
# 0  JAM_STAND_STILL_TRAFFIC                          NaN            0.0
#
#     longitude  latitude          pub_date_x     dates_x hour_x      id_y  \
# 0  107.044226 -6.270431 2020-09-25 10:10:24  2020-09-25     10  12454338
#
#    detection_date_millis  update_date_millis      street_y          city_y  \
# 0          1601005939233       1601008279450  Lambang Jaya  Tambun Selatan
#
#   is_highway                                               line  \
# 0          f  {"line": [{"x": 107.040272, "y": -6.268992}, {...
#
#            s2id_center s2token_center  speed  regular_speed  delay_seconds  \
# 0  3344360639261835264      2e698e484   6.75          25.63            362
#
#    seconds  length  trend type_y  severity  jam_level  drivers_count  \
# 0      440     827      1  Small         5          4              7
#
#    alerts_count  n_thumbs_up_y              pub_date_y     dates_y hour_y  \
# 0             0              0 2020-09-25 10:52:19.233  2020-09-25     10
#
#         lat         lon
# 0 -6.270088  107.043609

# %%
data['day'] = data['pub_date_y'].dt.day
data['month'] = data['pub_date_y'].dt.month

# %%
data.head(1)
# Out:
#                        Ids  Labels       id_x     pub_millis  \
# 0  2e698e484_2020-09-25_10    True  170560751  1601003424000
#
#                s2id_15 s2token_15  road_type      street_x          city_x  \
# 0  3344360639261835264  2e698e484          2  Lambang Jaya  Tambun Selatan
#
#    magvar  reliability  report_description  report_rating  confidence type_x  \
# 0     109            6                 NaN              2           0    JAM
#
#                    subtype  report_by_municipality_user  n_thumbs_up_x  \
# 0  JAM_STAND_STILL_TRAFFIC                          NaN            0.0
#
#     longitude  latitude          pub_date_x     dates_x hour_x      id_y  \
# 0  107.044226 -6.270431 2020-09-25 10:10:24  2020-09-25     10  12454338
#
#    detection_date_millis  update_date_millis      street_y          city_y  \
# 0          1601005939233       1601008279450  Lambang Jaya  Tambun Selatan
#
#   is_highway                                               line  \
# 0          f  {"line": [{"x": 107.040272, "y": -6.268992}, {...
#
#            s2id_center s2token_center  speed  regular_speed  delay_seconds  \
# 0  3344360639261835264      2e698e484   6.75          25.63            362
#
#    seconds  length  trend type_y  severity  jam_level  drivers_count  \
# 0      440     827      1  Small         5          4              7
#
#    alerts_count  n_thumbs_up_y              pub_date_y     dates_y hour_y  \
# 0             0              0 2020-09-25 10:52:19.233  2020-09-25     10
#
#         lat         lon  day  month
# 0 -6.270088  107.043609   25      9

# %%
dict_road_type = {}
for i in data['s2token_15'].unique():    
    dict_road_type[i] = data[data['s2token_15']==i]['road_type'].unique()[0]

# %%
data[data['s2token_15']==data['s2token_15'].unique()[2]]['street_x'].unique()
# Out:
# array([nan, 'KH Noer Ali', 'Arah Tol Jkt-Cikampek/Tol Lkr Dalam/Cawang'],
#       dtype=object)

# %%
data['token_hour'] = [i.split('_')[0]+'_'+i.split('_')[-1] for i in data['Ids']]

# %%
data['token_hour'].nunique()
# Out:
# 2580

# %%
database_street = data.groupby(['token_hour', 'street_x']).size().reset_index(name='Freq')
database_road_type = data.groupby(['token_hour', 'road_type']).size().reset_index(name='Freq')
database_jam_level = data.groupby(['token_hour', 'jam_level']).size().reset_index(name='Freq')

# %%
db_street = database_street.drop(database_street[database_street.duplicated('token_hour', keep='first')].index)

# %%
db_street.drop(columns='Freq', inplace=True)
db_street
# Out:
#         token_hour                                         street_x
# 0     2e68c2a5c_17                                 Arah Jalur Cepat
# 1     2e68c2a64_17                               N11 Soekarno-Hatta
# 2     2e68c2ae4_11                         Terusan Cisaranten Kulon
# 3     2e68c2ba4_12                               N11 Soekarno-Hatta
# 4     2e68c2ba4_17                               N11 Soekarno-Hatta
# ...            ...                                              ...
# 2746  2e69f2d4c_14                                 Arah Pondok Gede
# 2748  2e69f2d4c_15                                Jatiwaringin Raya
# 2749  2e69f2d4c_16                                    Anugerah Raya
# 2751  2e69f2d4c_17  Exit 04: Pondok Gede/Jatiwaringin/Pondok Kelapa
# 2753  2e69f2d4c_19                                Jatiwaringin Raya
#
# [2553 rows x 2 columns]

# %%
db_street['token_hour'].nunique()
# Out:
# 2553

# %%
db_road_type = database_road_type.drop(database_road_type[database_road_type.duplicated('token_hour', keep='first')].index)

# %%
db_road_type.drop(columns='Freq', inplace=True)
db_road_type
# Out:
#         token_hour  road_type
# 0     2e68c2a5c_17          7
# 1     2e68c2a64_17          6
# 2     2e68c2ae4_11          2
# 3     2e68c2ba4_12          6
# 4     2e68c2ba4_17          6
# ...            ...        ...
# 2753  2e69f2d4c_14          4
# 2754  2e69f2d4c_15          7
# 2755  2e69f2d4c_16          2
# 2757  2e69f2d4c_17          4
# 2759  2e69f2d4c_19          7
#
# [2580 rows x 2 columns]

# %%
db_jam_level = database_jam_level.drop(database_jam_level[database_jam_level.duplicated('token_hour', keep='first')].index)

# %%
db_jam_level.drop(columns='Freq', inplace=True)
db_jam_level
# Out:
#         token_hour  jam_level
# 0     2e68c2a5c_17          3
# 1     2e68c2a64_17          3
# 2     2e68c2ae4_11          4
# 3     2e68c2ba4_12          2
# 6     2e68c2ba4_17          2
# ...            ...        ...
# 3576  2e69f2d4c_14          3
# 3578  2e69f2d4c_15          4
# 3579  2e69f2d4c_16          4
# 3580  2e69f2d4c_17          3
# 3582  2e69f2d4c_19          4
#
# [2580 rows x 2 columns]

# %%
db_jam_level.isna().sum()
# Out:
# token_hour    0
# jam_level     0
# dtype: int64

# %%
ready = data[['token_hour','lat', 'lon', 'day', 'month', 'Labels', 'hour_y', 'street_x', 'road_type', 'jam_level']]
ready
# Out:
#            token_hour       lat         lon  day  month  Labels hour_y  \
# 0        2e698e484_10 -6.270088  107.043609   25      9    True     10
# 1        2e698e484_10 -6.270088  107.043609   25      9    True     10
# 2        2e698e484_10 -6.270088  107.043609   25      9    True     10
# 3        2e698e484_10 -6.270088  107.043609   25      9    True     10
# 4        2e698e484_10 -6.270088  107.043609   25      9    True     10
# ...               ...       ...         ...  ...    ...     ...    ...
# 3707443  2e68e6874_17 -6.886813  107.581583   22     11    True     17
# 3707444  2e68e6874_17 -6.886813  107.581583   22     11    True     17
# 3707445  2e68e6874_17 -6.886813  107.581583   22     11    True     17
# 3707446  2e68e6874_17 -6.886813  107.581583   22     11    True     17
# 3707447  2e68e6874_17 -6.886813  107.581583   22     11    True     17
#
#                        street_x  road_type  jam_level
# 0                  Lambang Jaya          2          4
# 1                  Lambang Jaya          2          4
# 2                  Lambang Jaya          2          4
# 3                  Lambang Jaya          2          3
# 4                  Lambang Jaya          2          4
# ...                         ...        ...        ...
# 3707443  Prof Dr Surya Sumantri          2          4
# 3707444  Prof Dr Surya Sumantri          2          4
# 3707445  Prof Dr Surya Sumantri          2          4
# 3707446  Prof Dr Surya Sumantri          2          4
# 3707447  Prof Dr Surya Sumantri          2          4
#
# [3707448 rows x 10 columns]

# %%
ready.isna().sum()/len(ready)*100
# Out:
# token_hour    0.000000
# lat           0.000000
# lon           0.000000
# day           0.000000
# month         0.000000
# Labels        0.000000
# hour_y        0.000000
# street_x      3.114649
# road_type     0.000000
# jam_level     0.000000
# dtype: float64

# %%
3707448 *3.114649/100
# Out:
# 115473.99205752001

# %%
ready_clean = ready.dropna()

# %%
ready_clean[ready_clean['Labels'] == True]['jam_level'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pd.crosstab(index=ready_clean['jam_level'], columns=ready_clean['Labels'], normalize=True).plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='jam_level'>

# %%
ready[ready['Labels'] == False]['jam_level'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ready.to_csv('ready.csv')

# %%
ready_clean.to_csv('ready_clean.csv', index=False)
print('done')
db_street.to_csv('db_street.csv', index=False)
print('done')
db_road_type.to_csv('db_road_type.csv', index=False)
print('done')
db_jam_level.to_csv('db_jam_level.csv', index=False)
print('done')
# Out:
# done
# done
# done
# done
